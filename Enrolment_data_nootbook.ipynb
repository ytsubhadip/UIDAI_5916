# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### load Enrolment data

# %%
enrolment1 = pd.read_csv("api_data_aadhar_enrolment/api_data_aadhar_enrolment/api_data_aadhar_enrolment_0_500000.csv")
enrolment2 = pd.read_csv("api_data_aadhar_enrolment/api_data_aadhar_enrolment/api_data_aadhar_enrolment_500000_1000000.csv")
enrolment3 = pd.read_csv("api_data_aadhar_enrolment/api_data_aadhar_enrolment/api_data_aadhar_enrolment_1000000_1006029.csv")

# %% [markdown]
# ## Enrolment 1 Dataset

# %%
enrolment1.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
enrolment1.shape
# Out:
# (500000, 7)

# %%
enrolment1.isnull().sum()
# Out:
# date              0
# state             0
# district          0
# pincode           0
# age_0_5           0
# age_5_17          0
# age_18_greater    0
# dtype: int64

# %%
state_list = list(enrolment1['state'].unique())

# %%
len(state_list)
# Out:
# 54

# %%
enrolment1["new_date"] = pd.to_datetime(enrolment1['date'], dayfirst=True).dt.strftime("%Y%m%d")

# %%
enrolment1.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater  new_date
# 0              37  20250302
# 1              39  20250309
# 2              12  20250309
# 3              15  20250309
# 4              21  20250309

# %%
enrolment1["new_date"].min() #strat date
# Out:
# '20250302'

# %%
enrolment1["new_date"].max() #End date
# Out:
# '20251026'

# %%
enrolment1['state'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'The Dadra And Nagar Haveli And Daman And Diu',
#        'Arunachal Pradesh', 'Himachal Pradesh', 'Goa',
#        'Jammu And Kashmir', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Ladakh', 'Andaman and Nicobar Islands', 'Orissa', 'Pondicherry',
#        'Puducherry', 'Lakshadweep', 'Andaman & Nicobar Islands',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman and Diu',
#        'WEST BENGAL', 'Jammu & Kashmir', 'West  Bengal', '100000',
#        'Daman & Diu', 'West Bangal', 'Westbengal', 'West bengal',
#        'andhra pradesh', 'ODISHA'], dtype=object)

# %% [markdown]
# ### Enrolment 2

# %%
enrolment2.head()
# Out:
#          date           state  district  pincode  age_0_5  age_5_17  \
# 0  26-10-2025  Andhra Pradesh  Nalgonda   508004        0         1
# 1  26-10-2025  Andhra Pradesh  Nalgonda   508238        1         0
# 2  26-10-2025  Andhra Pradesh  Nalgonda   508278        1         0
# 3  26-10-2025  Andhra Pradesh   Nandyal   518432        0         1
# 4  26-10-2025  Andhra Pradesh   Nandyal   518543        1         0
#
#    age_18_greater
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
enrolment2.shape
# Out:
# (500000, 7)

# %%
enrolment2["new_date"] = pd.to_datetime(enrolment2['date'], dayfirst=True).dt.strftime("%Y%m%d")

# %%
enrolment2.head()
# Out:
#          date           state  district  pincode  age_0_5  age_5_17  \
# 0  26-10-2025  Andhra Pradesh  Nalgonda   508004        0         1
# 1  26-10-2025  Andhra Pradesh  Nalgonda   508238        1         0
# 2  26-10-2025  Andhra Pradesh  Nalgonda   508278        1         0
# 3  26-10-2025  Andhra Pradesh   Nandyal   518432        0         1
# 4  26-10-2025  Andhra Pradesh   Nandyal   518543        1         0
#
#    age_18_greater  new_date
# 0               0  20251026
# 1               0  20251026
# 2               0  20251026
# 3               0  20251026
# 4               0  20251026

# %%
enrolment2.new_date.max() #start date
# Out:
# '20251231'

# %%
enrolment2.new_date.max() #End date
# Out:
# '20251231'

# %%
enrolment2.isnull().sum()
# Out:
# date              0
# state             0
# district          0
# pincode           0
# age_0_5           0
# age_5_17          0
# age_18_greater    0
# new_date          0
# dtype: int64

# %%
enrolment2['state'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'West Bengal',
#        'Chhattisgarh', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Bihar', 'Chandigarh', 'Sikkim', 'West Bangal',
#        'Dadra and Nagar Haveli', 'Daman and Diu',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Jammu & Kashmir',
#        'andhra pradesh', 'Dadra & Nagar Haveli', 'Westbengal',
#        'Daman & Diu', 'WESTBENGAL', 'West bengal', 'West  Bengal',
#        'WEST BENGAL', '100000'], dtype=object)

# %% [markdown]
# ### Enrolment 3

# %%
enrolment3.head()
# Out:
#          date      state district  pincode  age_0_5  age_5_17  age_18_greater
# 0  31-12-2025  Karnataka    Bidar   585330        2         3               0
# 1  31-12-2025  Karnataka    Bidar   585402        6         0               0
# 2  31-12-2025  Karnataka    Bidar   585413        1         0               0
# 3  31-12-2025  Karnataka    Bidar   585418        1         2               0
# 4  31-12-2025  Karnataka    Bidar   585421        4         3               0

# %%
enrolment3.shape
# Out:
# (6029, 7)

# %%
enrolment3["new_date"] = pd.to_datetime(enrolment3.date, dayfirst=True).dt.strftime("%Y%m%d")

# %%
enrolment3.head()
# Out:
#          date      state district  pincode  age_0_5  age_5_17  age_18_greater  \
# 0  31-12-2025  Karnataka    Bidar   585330        2         3               0
# 1  31-12-2025  Karnataka    Bidar   585402        6         0               0
# 2  31-12-2025  Karnataka    Bidar   585413        1         0               0
# 3  31-12-2025  Karnataka    Bidar   585418        1         2               0
# 4  31-12-2025  Karnataka    Bidar   585421        4         3               0
#
#    new_date
# 0  20251231
# 1  20251231
# 2  20251231
# 3  20251231
# 4  20251231

# %%
enrolment3["new_date"].min()
# Out:
# '20251231'

# %%
enrolment3["new_date"].max()
# Out:
# '20251231'

# %%
enrolment3.isnull().sum()
# Out:
# date              0
# state             0
# district          0
# pincode           0
# age_0_5           0
# age_5_17          0
# age_18_greater    0
# new_date          0
# dtype: int64

# %%
enrolment3.state.unique()
# Out:
# array(['Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Orissa', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Daman and Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Pondicherry'], dtype=object)

# %% [markdown]
# ### Main Dataset create

# %% [markdown]
# ### marge three dataset in one dataframe

# %%
df = pd.concat([enrolment1, enrolment2, enrolment3], axis=0, ignore_index=True)

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater  new_date
# 0              37  20250302
# 1              39  20250309
# 2              12  20250309
# 3              15  20250309
# 4              21  20250309

# %%
df.shape # total records in this dataset
# Out:
# (1006029, 8)

# %% [markdown]
# ### enrolment start date

# %%
df['new_date'].min()
# Out:
# '20250302'

# %% [markdown]
# ### enrolment end date

# %%
df['new_date'].max()
# Out:
# '20251231'

# %%
df['state'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'The Dadra And Nagar Haveli And Daman And Diu',
#        'Arunachal Pradesh', 'Himachal Pradesh', 'Goa',
#        'Jammu And Kashmir', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Ladakh', 'Andaman and Nicobar Islands', 'Orissa', 'Pondicherry',
#        'Puducherry', 'Lakshadweep', 'Andaman & Nicobar Islands',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman and Diu',
#        'WEST BENGAL', 'Jammu & Kashmir', 'West  Bengal', '100000',
#        'Daman & Diu', 'West Bangal', 'Westbengal', 'West bengal',
#        'andhra pradesh', 'ODISHA', 'WESTBENGAL'], dtype=object)

# %%
df['state'].nunique()
# Out:
# 55

# %%
df = df[df['state'] != '100000']

# %%
import pandas as pd
import string

# Get unique states
unique_states = df['state'].unique()

# Loop through letters A to Z
for letter in string.ascii_uppercase:
    # Find states that start with this letter (case-insensitive)
    matches = [state for state in unique_states if str(state).lower().startswith(letter.lower())]
    
    # Only print if we found matches for this letter
    if matches:
        print(f"--- {letter} ---")
        for state in matches:
            print(state)
        print() # New line
# Out:
# --- A ---
# Assam
# Andhra Pradesh
# Arunachal Pradesh
# Andaman and Nicobar Islands
# Andaman & Nicobar Islands
# andhra pradesh
#
# --- B ---
# Bihar
#
# --- C ---
# Chhattisgarh
# Chandigarh
#
# --- D ---
# Delhi
# Dadra and Nagar Haveli and Daman and Diu
# Dadra & Nagar Haveli
# Dadra and Nagar Haveli
# Daman and Diu
# Daman & Diu
#
# --- G ---
# Gujarat
# Goa
#
# --- H ---
# Haryana
# Himachal Pradesh
#
# --- J ---
# Jharkhand
# Jammu and Kashmir
# Jammu And Kashmir
# Jammu & Kashmir
#
# --- K ---
# Karnataka
# Kerala
#
# --- L ---
# Ladakh
# Lakshadweep
#
# --- M ---
# Meghalaya
# Maharashtra
# Madhya Pradesh
# Manipur
# Mizoram
#
# --- N ---
# Nagaland
#
# --- O ---
# Odisha
# Orissa
# ODISHA
#
# --- P ---
# Punjab
# Pondicherry
# Puducherry
#
# --- R ---
# Rajasthan
#
# --- S ---
# Sikkim
#
# --- T ---
# Tamil Nadu
# Telangana
# Tripura
# The Dadra And Nagar Haveli And Daman And Diu
#
# --- U ---
# Uttar Pradesh
# Uttarakhand
#
# --- W ---
# West Bengal
# WEST BENGAL
# West  Bengal
# West Bangal
# Westbengal
# West bengal
# WESTBENGAL

# %% [markdown]
# ### Clean State Dataset

# %%
# state maping

state_maping = {
    "andhra pradesh":"Andhra Pradesh",
    
    "Andaman & Nicobar Islands":"Andaman and Nicobar Islands",
    "Andaman and Nicobar Islands": "Andaman and Nicobar Islands",
    
    "meghalaya":"Meghalaya",
    
    "WEST BENGAL":"West Bengal",
    "West bengal":"West Bengal",
    "WETSBENGAL": "West Bengal",
    "West Bengal":"West Bengal",
    "West Bangal": "West Bengal",
    "Westbengal" : "West Bengal",
    "WESTBENGAL":"West Bengal",
    "West  Bengal":"West Bengal",
    
    
    "Odisha": "Odisha",
    "ODISHA":"Odisha",
    "Orissa":"Odisha",
    
    "Dadra and Nagar Haveli and Daman and Diu":"Dadra and Nagar Haveli and Daman and Diu",
    "Dadra & Nagar Haveli":"Dadra and Nagar Haveli and Daman and Diu",
    "Dadra and Nagar Haveli":"Dadra and Nagar Haveli and Daman and Diu",
    "Daman and Diu":"Dadra and Nagar Haveli and Daman and Diu",
    "Daman & Diu": "Dadra and Nagar Haveli and Daman and Diu",
    "The Dadra And Nagar Haveli And Daman And Diu": "Dadra and Nagar Haveli and Daman and Diu",
    
    "Jammu and Kashmir":"Jammu and Kashmir",
    "Jammu And Kashmir":"Jammu and Kashmir",
    "Jammu & Kashmir":"Jammu and Kashmir",

    "Puducherry":"Pundicherry",
    "Pondicherry": "Pundicherry",
    
}

# %%
df["clean_state"] = df['state'].replace(state_maping)

# %%
df.tail()
# Out:
#                date        state        district  pincode  age_0_5  age_5_17  \
# 1006024  31-12-2025  West Bengal  West Midnapore   721149        2         0
# 1006025  31-12-2025  West Bengal  West Midnapore   721150        2         2
# 1006026  31-12-2025  West Bengal  West Midnapore   721305        0         1
# 1006027  31-12-2025  West Bengal  West Midnapore   721504        1         0
# 1006028  31-12-2025  West Bengal  West Midnapore   721517        2         1
#
#          age_18_greater  new_date  clean_state
# 1006024               0  20251231  West Bengal
# 1006025               0  20251231  West Bengal
# 1006026               0  20251231  West Bengal
# 1006027               0  20251231  West Bengal
# 1006028               0  20251231  West Bengal

# %%
df["clean_state"].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Arunachal Pradesh',
#        'Himachal Pradesh', 'Goa', 'Ladakh', 'Andaman and Nicobar Islands',
#        'Pundicherry', 'Lakshadweep'], dtype=object)

# %% [markdown]
# ### Clean state Data

# %%
import pandas as pd
import string

# Get unique states
unique_states = df['clean_state'].unique()

# Loop through letters A to Z
for letter in string.ascii_uppercase:
    # Find states that start with this letter (case-insensitive)
    matches = [state for state in unique_states if str(state).lower().startswith(letter.lower())]
    
    # Only print if we found matches for this letter
    if matches:
        print(f"--- {letter} ---")
        for state in matches:
            print(state)
        print() # New line
# Out:
# --- A ---
# Assam
# Andhra Pradesh
# Arunachal Pradesh
# Andaman and Nicobar Islands
#
# --- B ---
# Bihar
#
# --- C ---
# Chhattisgarh
# Chandigarh
#
# --- D ---
# Delhi
# Dadra and Nagar Haveli and Daman and Diu
#
# --- G ---
# Gujarat
# Goa
#
# --- H ---
# Haryana
# Himachal Pradesh
#
# --- J ---
# Jharkhand
# Jammu and Kashmir
#
# --- K ---
# Karnataka
# Kerala
#
# --- L ---
# Ladakh
# Lakshadweep
#
# --- M ---
# Meghalaya
# Maharashtra
# Madhya Pradesh
# Manipur
# Mizoram
#
# --- N ---
# Nagaland
#
# --- O ---
# Odisha
#
# --- P ---
# Punjab
# Pundicherry
#
# --- R ---
# Rajasthan
#
# --- S ---
# Sikkim
#
# --- T ---
# Tamil Nadu
# Telangana
# Tripura
#
# --- U ---
# Uttar Pradesh
# Uttarakhand
#
# --- W ---
# West Bengal

# %% [markdown]
# ## check district

# %%
bihar_state = df[df['clean_state'] == 'Bihar'].copy()

# %%
bihar_state['district'].nunique()  #number of district in bihar 38
# Out:
# 48

# %%
bihar_state["district"].unique()
# Out:
# array(['Sitamarhi', 'Purbi Champaran', 'Madhubani', 'Bhagalpur', 'Patna',
#        'Pashchim Champaran', 'Muzaffarpur', 'Munger', 'Gaya',
#        'Kaimur (Bhabua)', 'West Champaran', 'Purnia', 'Saran',
#        'East Champaran', 'Vaishali', 'Jehanabad', 'Jamui', 'Gopalganj',
#        'Saharsa', 'Arwal', 'Katihar', 'Siwan', 'Lakhisarai', 'Banka',
#        'Nalanda', 'Araria', 'Darbhanga', 'Nawada', 'Samastipur',
#        'Begusarai', 'Bhojpur', 'Aurangabad', 'Buxar', 'Khagaria',
#        'Kishanganj', 'Madhepura', 'Rohtas', 'Sheohar', 'Supaul',
#        'Aurangabad(bh)', 'Purba Champaran', 'Purnea', 'Sheikhpura',
#        'Sheikpura', 'Bhabua', 'Monghyr', 'Samstipur', 'Aurangabad(BH)'],
#       dtype=object)

# %%
import pandas as pd
import string

# Get unique states
unique_district = bihar_state['district'].unique()

# Loop through letters A to Z
for letter in string.ascii_uppercase:
    # Find states that start with this letter (case-insensitive)
    matches = [state for state in unique_district if str(state).lower().startswith(letter.lower())]
    
    # Only print if we found matches for this letter
    if matches:
        print(f"--- {letter} ---")
        for state in matches:
            print(state)
        print() # New line
# Out:
# --- A ---
# Arwal
# Araria
# Aurangabad
# Aurangabad(bh)
# Aurangabad(BH)
#
# --- B ---
# Bhagalpur
# Banka
# Begusarai
# Bhojpur
# Buxar
# Bhabua
#
# --- D ---
# Darbhanga
#
# --- E ---
# East Champaran
#
# --- G ---
# Gaya
# Gopalganj
#
# --- J ---
# Jehanabad
# Jamui
#
# --- K ---
# Kaimur (Bhabua)
# Katihar
# Khagaria
# Kishanganj
#
# --- L ---
# Lakhisarai
#
# --- M ---
# Madhubani
# Muzaffarpur
# Munger
# Madhepura
# Monghyr
#
# --- N ---
# Nalanda
# Nawada
#
# --- P ---
# Purbi Champaran
# Patna
# Pashchim Champaran
# Purnia
# Purba Champaran
# Purnea
#
# --- R ---
# Rohtas
#
# --- S ---
# Sitamarhi
# Saran
# Saharsa
# Siwan
# Samastipur
# Sheohar
# Supaul
# Sheikhpura
# Sheikpura
# Samstipur
#
# --- V ---
# Vaishali
#
# --- W ---
# West Champaran

# %%
## remove space and symbol
import re
import pandas as pd

def clean_name(x):
    # 1. Check if the value is missing (NaN)
    if pd.isna(x):
        return x
    
    # 2. Convert to string and make it lowercase
    x = str(x).lower()
    
    # 3. Remove symbols: replace anything that is NOT a letter (a-z) 
    # or a space (\s) with a single space
    x = re.sub(r'[^a-z\s]', ' ', x)  # removes (), ., &, etc.
    
    # 4. Remove extra spaces: replace multiple spaces with one 
    # and remove leading/trailing spaces
    x = re.sub(r'\s+', ' ', x).strip()
    
    return x

# %% [markdown]
# ### Clean Bihar District

# %%
# Yeh dictionary "Galat/Duplicate Naam" ko "Sahi Naam" se map karegi
bihar_district_mapping = {
 # --- Champaran (Hindi/Variations -> English) ---
    'Purbi Champaran': 'East Champaran',
    'Purba Champaran': 'East Champaran',
    'Pashchim Champaran': 'West Champaran',
    
    # --- Aurangabad (Removing 'BH' codes) ---
    'Aurangabad(bh)': 'Aurangabad',
    'Aurangabad(BH)': 'Aurangabad',
    
    # --- Spelling Corrections (Typos) ---
    'Samstipur': 'Samastipur',   # Missing 'a'
    'Sheikpura': 'Sheikhpura',   # Missing 'h'
    'Purnea': 'Purnia',          # Alternative spelling
    
    # --- Old Names ---
    'Monghyr': 'Munger',         # British era name
    
    # --- Kaimur / Bhabua Standardization ---
    'Bhabua': 'Kaimur (Bhabua)', # Maps HQ name to District name
    
    # --- Capitalization Fixes ---
    'kishanganj': 'Kishanganj'
    

}

# %%
bihar_state["clean_district"] = bihar_state["district"].replace(bihar_district_mapping)

# %%
bihar_state["clean_district"].unique()
# Out:
# array(['Sitamarhi', 'East Champaran', 'Madhubani', 'Bhagalpur', 'Patna',
#        'West Champaran', 'Muzaffarpur', 'Munger', 'Gaya',
#        'Kaimur (Bhabua)', 'Purnia', 'Saran', 'Vaishali', 'Jehanabad',
#        'Jamui', 'Gopalganj', 'Saharsa', 'Arwal', 'Katihar', 'Siwan',
#        'Lakhisarai', 'Banka', 'Nalanda', 'Araria', 'Darbhanga', 'Nawada',
#        'Samastipur', 'Begusarai', 'Bhojpur', 'Aurangabad', 'Buxar',
#        'Khagaria', 'Kishanganj', 'Madhepura', 'Rohtas', 'Sheohar',
#        'Supaul', 'Sheikhpura'], dtype=object)

# %%
bihar_state["clean_district"].nunique()
# Out:
# 38

# %%
import pandas as pd
import string

# Get unique states
unique_district = bihar_state['clean_district'].unique()

# Loop through letters A to Z
for letter in string.ascii_uppercase:
    # Find states that start with this letter (case-insensitive)
    matches = [state for state in unique_district if str(state).lower().startswith(letter.lower())]
    
    # Only print if we found matches for this letter
    if matches:
        print(f"--- {letter} ---")
        for state in matches:
            print(state)
        print() # New line
# Out:
# --- A ---
# Arwal
# Araria
# Aurangabad
#
# --- B ---
# Bhagalpur
# Banka
# Begusarai
# Bhojpur
# Buxar
#
# --- D ---
# Darbhanga
#
# --- E ---
# East Champaran
#
# --- G ---
# Gaya
# Gopalganj
#
# --- J ---
# Jehanabad
# Jamui
#
# --- K ---
# Kaimur (Bhabua)
# Katihar
# Khagaria
# Kishanganj
#
# --- L ---
# Lakhisarai
#
# --- M ---
# Madhubani
# Muzaffarpur
# Munger
# Madhepura
#
# --- N ---
# Nalanda
# Nawada
#
# --- P ---
# Patna
# Purnia
#
# --- R ---
# Rohtas
#
# --- S ---
# Sitamarhi
# Saran
# Saharsa
# Siwan
# Samastipur
# Sheohar
# Supaul
# Sheikhpura
#
# --- V ---
# Vaishali
#
# --- W ---
# West Champaran

# %% [markdown]
# ### Clean pincode data in Bihar

# %%
bihar_state['pincode'].nunique()
# Out:
# 906

# %% [markdown]
# ### Check number of pincode in each district

# %%
pincode_check = bihar_state.groupby('clean_district')['pincode'].nunique().reset_index(name="unique_pincode_count")

# %%
pincode_check
# Out:
#      clean_district  unique_pincode_count
# 0            Araria                    19
# 1             Arwal                    19
# 2        Aurangabad                    29
# 3             Banka                    32
# 4         Begusarai                    33
# 5         Bhagalpur                    34
# 6           Bhojpur                    41
# 7             Buxar                    27
# 8         Darbhanga                    46
# 9    East Champaran                    39
# 10             Gaya                    39
# 11        Gopalganj                    23
# 12            Jamui                    14
# 13        Jehanabad                    21
# 14  Kaimur (Bhabua)                    12
# 15          Katihar                    23
# 16         Khagaria                    15
# 17       Kishanganj                     9
# 18       Lakhisarai                    13
# 19        Madhepura                    21
# 20        Madhubani                    44
# 21           Munger                    12
# 22      Muzaffarpur                    53
# 23          Nalanda                    31
# 24           Nawada                    24
# 25            Patna                    69
# 26           Purnia                    30
# 27           Rohtas                    33
# 28          Saharsa                    18
# 29       Samastipur                    42
# 30            Saran                    51
# 31       Sheikhpura                     8
# 32          Sheohar                     7
# 33        Sitamarhi                    25
# 34            Siwan                    46
# 35           Supaul                    23
# 36         Vaishali                    38
# 37   West Champaran                    19

# %%
# max pincode district
pincode_check[pincode_check["unique_pincode_count"] == pincode_check["unique_pincode_count"].max()]
# Out:
#    clean_district  unique_pincode_count
# 25          Patna                    69

# %%
# min pin code district 
pincode_check[pincode_check["unique_pincode_count"] == pincode_check["unique_pincode_count"].min()]
# Out:
#    clean_district  unique_pincode_count
# 32        Sheohar                     7

# %%
bihar_state[bihar_state["clean_district"] == "Patna"]["pincode"].unique()
# Out:
# array([800001, 801505, 800002, 800014, 801503, 803201, 800008, 800004,
#        800026, 800006, 800007, 801110, 800020, 800023, 800111, 801109,
#        804453, 800009, 800013, 803212, 801103, 801113, 803214, 803301,
#        804454, 811104, 800018, 800024, 801105, 801112, 803303, 804423,
#        800010, 800012, 800016, 801102, 801108, 803110, 803202, 803206,
#        803302, 804451, 804452, 800003, 800027, 801104, 801117, 801502,
#        801506, 803203, 803211, 803213, 800025, 801118, 802160, 803221,
#        804401, 800011, 801507, 804426, 801304, 803307, 803306, 801305,
#        800022, 811302, 800030, 800028, 800005])

# %%
# number of district in one pincode
district_pincode_count = bihar_state.groupby("pincode")["clean_district"].nunique().reset_index(name="district_count")

# %%
district_pincode_count
# Out:
#      pincode  district_count
# 0     800001               1
# 1     800002               1
# 2     800003               1
# 3     800004               1
# 4     800005               1
# ..       ...             ...
# 901   855114               1
# 902   855115               2
# 903   855116               1
# 904   855117               1
# 905   855456               1
#
# [906 rows x 2 columns]

# %%
probleam_pincode = district_pincode_count[district_pincode_count["district_count"]>=2]

# %%
probleam_pincode.shape
# Out:
# (165, 2)

# %%
district_pincode_count.district_count.unique() # number of pincode avialabe district count
# Out:
# array([1, 2, 3, 4])

# %%
#create a flagg
df_flagg_pincode = bihar_state.merge(probleam_pincode[["pincode"]], on="pincode", how="inner")

# %%
df_flagg_pincode.head()
# Out:
#          date  state   district  pincode  age_0_5  age_5_17  age_18_greater  \
# 0  01-04-2025  Bihar  Sitamarhi   843315      102       125              18
# 1  01-04-2025  Bihar     Munger   811213      191       278              22
# 2  01-04-2025  Bihar  Bhagalpur   853204      349       238              10
# 3  01-04-2025  Bihar     Purnia   854304      517       276              21
# 4  01-04-2025  Bihar       Gaya   824233       63       317              13
#
#    new_date clean_state clean_district
# 0  20250401       Bihar      Sitamarhi
# 1  20250401       Bihar         Munger
# 2  20250401       Bihar      Bhagalpur
# 3  20250401       Bihar         Purnia
# 4  20250401       Bihar           Gaya

# %%
flagged_pincode_dominant= df_flagg_pincode.groupby(["clean_district","pincode"])[["age_0_5","age_5_17","age_18_greater"]].sum().reset_index()

# %%
flagged_pincode_dominant.iloc[:10,:]
# Out:
#   clean_district  pincode  age_0_5  age_5_17  age_18_greater
# 0         Araria   854102      131        86               1
# 1         Araria   854201       31        33               0
# 2         Araria   854202       58        74               0
# 3         Araria   854304      410       412              14
# 4         Araria   854312      837       546               6
# 5         Araria   854325      573       190               1
# 6         Araria   854327       22         6               0
# 7         Araria   854329      895       245               7
# 8         Araria   854332      243        83               2
# 9         Araria   854333     1118       408               9

# %%
flagged_pincode_dominant["total_enrolment"] = flagged_pincode_dominant["age_0_5"]+flagged_pincode_dominant["age_5_17"]+flagged_pincode_dominant["age_18_greater"]

# %%
flagged_pincode_dominant.sort_values("pincode")
# Out:
#     clean_district  pincode  age_0_5  age_5_17  age_18_greater  \
# 211        Nalanda   801304       58       114               0
# 229          Patna   801304       17        36               1
# 212        Nalanda   801305       39        62               1
# 230          Patna   801305       12        33               2
# 57         Bhojpur   802112       48       131               0
# ..             ...      ...      ...       ...             ...
# 258         Purnia   855105       61        18               2
# 259         Purnia   855107      235        70               0
# 154     Kishanganj   855107     1685       446               1
# 155     Kishanganj   855115      774       208               4
# 260         Purnia   855115      222        60               0
#
#      total_enrolment
# 211              172
# 229               54
# 212              102
# 230               47
# 57               179
# ..               ...
# 258               81
# 259              305
# 154             2132
# 155              986
# 260              282
#
# [341 rows x 6 columns]

# %%
### check month how enrolment in this dataset

# %%
bihar_state["month"] = bihar_state["new_date"].astype(str).str[4:6]

# %%
bihar_state["total_enrolment"] = bihar_state["age_0_5"]+bihar_state["age_5_17"]+bihar_state["age_18_greater"]

# %%
bihar_state
# Out:
#                date  state         district  pincode  age_0_5  age_5_17  \
# 5        09-03-2025  Bihar        Sitamarhi   843331       20        49
# 6        09-03-2025  Bihar        Sitamarhi   843330       23        24
# 9        09-03-2025  Bihar  Purbi Champaran   845418       30        48
# 11       09-03-2025  Bihar        Sitamarhi   843317       35        94
# 13       09-03-2025  Bihar        Sitamarhi   843324       49       186
# ...             ...    ...              ...      ...      ...       ...
# 1002992  31-12-2025  Bihar         Vaishali   844134        2         0
# 1002993  31-12-2025  Bihar         Vaishali   844504       15        26
# 1002994  31-12-2025  Bihar         Vaishali   844509        1         2
# 1002995  31-12-2025  Bihar   West Champaran   845404       13        17
# 1002996  31-12-2025  Bihar   West Champaran   845449        9        45
#
#          age_18_greater  new_date clean_state  clean_district month  \
# 5                    12  20250309       Bihar       Sitamarhi    03
# 6                    42  20250309       Bihar       Sitamarhi    03
# 9                    10  20250309       Bihar  East Champaran    03
# 11                   16  20250309       Bihar       Sitamarhi    03
# 13                   34  20250309       Bihar       Sitamarhi    03
# ...                 ...       ...         ...             ...   ...
# 1002992               0  20251231       Bihar        Vaishali    12
# 1002993               1  20251231       Bihar        Vaishali    12
# 1002994               0  20251231       Bihar        Vaishali    12
# 1002995               1  20251231       Bihar  West Champaran    12
# 1002996               0  20251231       Bihar  West Champaran    12
#
#          total_enrolment
# 5                     81
# 6                     89
# 9                     88
# 11                   145
# 13                   269
# ...                  ...
# 1002992                2
# 1002993               42
# 1002994                3
# 1002995               31
# 1002996               54
#
# [60567 rows x 12 columns]

# %%
df_bihar_clean = bihar_state.drop(columns=["date", "state","district"], axis="columns")
df_bihar_clean
# Out:
#          pincode  age_0_5  age_5_17  age_18_greater  new_date clean_state  \
# 5         843331       20        49              12  20250309       Bihar
# 6         843330       23        24              42  20250309       Bihar
# 9         845418       30        48              10  20250309       Bihar
# 11        843317       35        94              16  20250309       Bihar
# 13        843324       49       186              34  20250309       Bihar
# ...          ...      ...       ...             ...       ...         ...
# 1002992   844134        2         0               0  20251231       Bihar
# 1002993   844504       15        26               1  20251231       Bihar
# 1002994   844509        1         2               0  20251231       Bihar
# 1002995   845404       13        17               1  20251231       Bihar
# 1002996   845449        9        45               0  20251231       Bihar
#
#          clean_district month  total_enrolment
# 5             Sitamarhi    03               81
# 6             Sitamarhi    03               89
# 9        East Champaran    03               88
# 11            Sitamarhi    03              145
# 13            Sitamarhi    03              269
# ...                 ...   ...              ...
# 1002992        Vaishali    12                2
# 1002993        Vaishali    12               42
# 1002994        Vaishali    12                3
# 1002995  West Champaran    12               31
# 1002996  West Champaran    12               54
#
# [60567 rows x 9 columns]

# %%
df_bihar_dist_level = df_bihar_clean.groupby("clean_district")[["age_0_5","age_5_17","age_18_greater", "total_enrolment"]].sum()

# %%
df_bihar_dist_level
# Out:
#                  age_0_5  age_5_17  age_18_greater  total_enrolment
# clean_district
# Araria              9939      5515             125            15579
# Arwal                812      3020              34             3866
# Aurangabad          3050      7160              73            10283
# Banka               6198      4797              79            11074
# Begusarai           8106      5045              58            13209
# Bhagalpur          10456     10229             377            21062
# Bhojpur             3136     10115             106            13357
# Buxar               2528      4648              64             7240
# Darbhanga          10017      5677              71            15765
# East Champaran     14208     28508            1605            44321
# Gaya                6722     20244             435            27401
# Gopalganj           5303      9649             196            15148
# Jamui               5193      5029             160            10382
# Jehanabad            915      3827             141             4883
# Kaimur (Bhabua)     3047      4724              85             7856
# Katihar            11332      4903             115            16350
# Khagaria            4348      3779              69             8196
# Kishanganj          6957      1782              25             8764
# Lakhisarai          2664      3423              68             6155
# Madhepura           4571      4417              39             9027
# Madhubani          12598     12534             798            25930
# Munger              2474      3554             108             6136
# Muzaffarpur        14087     14103             665            28855
# Nalanda             3676     10763             136            14575
# Nawada              2742     12380             291            15413
# Patna               6745     17151             748            24644
# Purnia             12364      7809             184            20357
# Rohtas              2741      5120              78             7939
# Saharsa             6281      6577             205            13063
# Samastipur         11330      7828             131            19289
# Saran               7592     16407             219            24218
# Sheikhpura          1255      1952              21             3228
# Sheohar             2067      1184              11             3262
# Sitamarhi          20679     18856            2697            42232
# Siwan               6149      9025             137            15311
# Supaul              5691      4563             157            10411
# Vaishali            8257      9698              52            18007
# West Champaran     16645     28807            1345            46797

# %%
df_bihar_dist_level.sort_values("total_enrolment",ascending=False).reset_index()
# Out:
#      clean_district  age_0_5  age_5_17  age_18_greater  total_enrolment
# 0    West Champaran    16645     28807            1345            46797
# 1    East Champaran    14208     28508            1605            44321
# 2         Sitamarhi    20679     18856            2697            42232
# 3       Muzaffarpur    14087     14103             665            28855
# 4              Gaya     6722     20244             435            27401
# 5         Madhubani    12598     12534             798            25930
# 6             Patna     6745     17151             748            24644
# 7             Saran     7592     16407             219            24218
# 8         Bhagalpur    10456     10229             377            21062
# 9            Purnia    12364      7809             184            20357
# 10       Samastipur    11330      7828             131            19289
# 11         Vaishali     8257      9698              52            18007
# 12          Katihar    11332      4903             115            16350
# 13        Darbhanga    10017      5677              71            15765
# 14           Araria     9939      5515             125            15579
# 15           Nawada     2742     12380             291            15413
# 16            Siwan     6149      9025             137            15311
# 17        Gopalganj     5303      9649             196            15148
# 18          Nalanda     3676     10763             136            14575
# 19          Bhojpur     3136     10115             106            13357
# 20        Begusarai     8106      5045              58            13209
# 21          Saharsa     6281      6577             205            13063
# 22            Banka     6198      4797              79            11074
# 23           Supaul     5691      4563             157            10411
# 24            Jamui     5193      5029             160            10382
# 25       Aurangabad     3050      7160              73            10283
# 26        Madhepura     4571      4417              39             9027
# 27       Kishanganj     6957      1782              25             8764
# 28         Khagaria     4348      3779              69             8196
# 29           Rohtas     2741      5120              78             7939
# 30  Kaimur (Bhabua)     3047      4724              85             7856
# 31            Buxar     2528      4648              64             7240
# 32       Lakhisarai     2664      3423              68             6155
# 33           Munger     2474      3554             108             6136
# 34        Jehanabad      915      3827             141             4883
# 35            Arwal      812      3020              34             3866
# 36          Sheohar     2067      1184              11             3262
# 37       Sheikhpura     1255      1952              21             3228

# %%
bihar_dist_level1 = df_bihar_dist_level.head(10)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 6))
sns.lineplot(data =bihar_dist_level1[["age_0_5","age_5_17","age_18_greater"]] )
plt.show()

# %%
bihar_pincode_level1=  df_bihar_clean.groupby("pincode")[["age_0_5","age_5_17","age_18_greater", "total_enrolment"]].sum()

# %%
bihar_pincode_level1= bihar_pincode_level1.head(10)

# %%
import matplotlib.pyplot as plt
import seaborn as ses
plt.figure(figsize=(19,6))
ses.lineplot(data= bihar_pincode_level1[["age_0_5","age_5_17","age_18_greater"]])
plt.show()

# %%
bihar_month_level1=  df_bihar_clean.groupby("month")[["age_0_5","age_5_17","age_18_greater", "total_enrolment"]].sum()

# %%
import matplotlib.pyplot as plt
import seaborn as ses
plt.figure(figsize=(19,6))
ses.lineplot(data= bihar_month_level1[["age_0_5","age_5_17","age_18_greater"]])
plt.show()
