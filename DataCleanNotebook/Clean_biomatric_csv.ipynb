# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("api_data_aadhar_biometric/api_data_aadhar_biometric/api_data_aadhar_biometric_0_500000.csv")
df2 = pd.read_csv("api_data_aadhar_biometric/api_data_aadhar_biometric/api_data_aadhar_biometric_500000_1000000.csv")
df3 = pd.read_csv("api_data_aadhar_biometric/api_data_aadhar_biometric/api_data_aadhar_biometric_1000000_1500000.csv")
df4 = pd.read_csv("api_data_aadhar_biometric/api_data_aadhar_biometric/api_data_aadhar_biometric_1500000_1861108.csv")

# %%
df = pd.concat([df1,df2,df3,df4],axis=0, ignore_index=True)

# %%
df.head(10)
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
# 5  01-03-2025        Maharashtra     Ratnagiri   416702           155
# 6  01-03-2025            Gujarat         Anand   388130            75
# 7  01-03-2025            Gujarat   Gandhinagar   382421           192
# 8  01-03-2025             Odisha     Dhenkanal   759025           122
# 9  01-03-2025            Gujarat        Valsad   396055            67
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815
# 5          529
# 6          143
# 7          298
# 8          214
# 9           85

# %%
print(df.shape) # total number of records
# Out:
# (1861108, 6)

# %%
print(df.columns)# total columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1861108 entries, 0 to 1861107
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          object
#  1   state         object
#  2   district      object
#  3   pincode       int64
#  4   bio_age_5_17  int64
#  5   bio_age_17_   int64
# dtypes: int64(3), object(3)
# memory usage: 85.2+ MB

# %%
df.describe()
# Out:
#             pincode  bio_age_5_17   bio_age_17_
# count  1.861108e+06  1.861108e+06  1.861108e+06
# mean   5.217612e+05  1.839058e+01  1.909413e+01
# std    1.981627e+05  8.370421e+01  8.806502e+01
# min    1.100010e+05  0.000000e+00  0.000000e+00
# 25%    3.911750e+05  1.000000e+00  1.000000e+00
# 50%    5.224010e+05  3.000000e+00  4.000000e+00
# 75%    6.866362e+05  1.100000e+01  1.000000e+01
# max    8.554560e+05  8.002000e+03  7.625000e+03

# %%
df_copy = df.copy() #create a copy dataframe

# %%
df_copy["date"]
# Out:
# 0          01-03-2025
# 1          01-03-2025
# 2          01-03-2025
# 3          01-03-2025
# 4          01-03-2025
#               ...
# 1861103    29-12-2025
# 1861104    29-12-2025
# 1861105    29-12-2025
# 1861106    29-12-2025
# 1861107    29-12-2025
# Name: date, Length: 1861108, dtype: object

# %%
df_copy['date'] = pd.to_datetime(df_copy['date'], format="%d-%m-%Y", errors='coerce')

# %%
df_copy["date"]
# Out:
# 0         2025-03-01
# 1         2025-03-01
# 2         2025-03-01
# 3         2025-03-01
# 4         2025-03-01
#              ...
# 1861103   2025-12-29
# 1861104   2025-12-29
# 1861105   2025-12-29
# 1861106   2025-12-29
# 1861107   2025-12-29
# Name: date, Length: 1861108, dtype: datetime64[ns]

# %%
#check null values
df_copy.isnull().sum()
# Out:
# date            0
# state           0
# district        0
# pincode         0
# bio_age_5_17    0
# bio_age_17_     0
# dtype: int64

# %%
#clean the text
df_copy['state'] = df_copy['state'].str.strip().str.title()
df_copy['district'] = df_copy['district'].str.strip().str.title()

# %%
df_copy.state.unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu And Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Orissa',
#        'Puducherry', 'Pondicherry', 'Manipur', 'Sikkim', 'Tripura',
#        'Mizoram', 'Arunachal Pradesh', 'Ladakh',
#        'Dadra And Nagar Haveli And Daman And Diu', 'Daman And Diu',
#        'Andaman And Nicobar Islands', 'Andaman & Nicobar Islands',
#        'Dadra And Nagar Haveli', 'Lakshadweep', 'Daman & Diu',
#        'Dadra & Nagar Haveli', 'Jammu & Kashmir', 'Westbengal',
#        'West  Bengal', 'West Bangal', 'Uttaranchal', 'Chhatisgarh',
#        'Tamilnadu'], dtype=object)

# %%
#remove the numaric column
df_copy = df_copy[~df_copy['state'].str.isnumeric()]

# %%
df_copy.state.unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu And Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Orissa',
#        'Puducherry', 'Pondicherry', 'Manipur', 'Sikkim', 'Tripura',
#        'Mizoram', 'Arunachal Pradesh', 'Ladakh',
#        'Dadra And Nagar Haveli And Daman And Diu', 'Daman And Diu',
#        'Andaman And Nicobar Islands', 'Andaman & Nicobar Islands',
#        'Dadra And Nagar Haveli', 'Lakshadweep', 'Daman & Diu',
#        'Dadra & Nagar Haveli', 'Jammu & Kashmir', 'Westbengal',
#        'West  Bengal', 'West Bangal', 'Uttaranchal', 'Chhatisgarh',
#        'Tamilnadu'], dtype=object)

# %%
# Normalise spacing and symbol
df_copy['state'] = (
    df_copy['state']
    .str.replace('&', 'And', regex=False)
    .str.replace(r'\s+', ' ', regex=True)
    .str.strip()
)

# %%
df_copy["state"].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu And Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Orissa',
#        'Puducherry', 'Pondicherry', 'Manipur', 'Sikkim', 'Tripura',
#        'Mizoram', 'Arunachal Pradesh', 'Ladakh',
#        'Dadra And Nagar Haveli And Daman And Diu', 'Daman And Diu',
#        'Andaman And Nicobar Islands', 'Dadra And Nagar Haveli',
#        'Lakshadweep', 'Westbengal', 'West Bangal', 'Uttaranchal',
#        'Chhatisgarh', 'Tamilnadu'], dtype=object)

# %%
# Mapping state
state_mapping = {
    "West Bangal": "West Bengal",
    "Westbengal": "West Bengal",
    "West  Bengal": "West Bengal",
    "Orissa": "Odisha",
    "Pondicherry": "Puducherry",
    "Jammu And Kashmir": "Jammu And Kashmir",
    "Jammu And Kashmir": "Jammu And Kashmir",
    "Dadra And Nagar Haveli": "Dadra And Nagar Haveli And Daman And Diu",
    "Daman And Diu": "Dadra And Nagar Haveli And Daman And Diu",
    "Dadra And Nagar Haveli And Daman And Diu":
        "Dadra And Nagar Haveli And Daman And Diu",
    "Andaman And Nicobar Islands": "Andaman And Nicobar Islands",
    "Andaman And Nicobar Islands": "Andaman And Nicobar Islands"
}
df_copy["state"] = df_copy["state"].replace(state_mapping)

# %%
state_list = list(sorted(df_copy["state"].unique()))

# %%
type(state_list)
# Out:
# list

# %%
state_list
# Out:
# ['Andaman And Nicobar Islands',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhatisgarh',
#  'Chhattisgarh',
#  'Dadra And Nagar Haveli And Daman And Diu',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu And Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Ladakh',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tamilnadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'Uttaranchal',
#  'West Bengal']

# %%
df_copy["district"].unique()
# Out:
# array(['Mahendragarh', 'Madhepura', 'Punch', 'Bhojpur', 'Madurai',
#        'Ratnagiri', 'Anand', 'Gandhinagar', 'Dhenkanal', 'Valsad',
#        'Salem', 'Hooghly', 'Paschim Medinipur', 'Wayanad',
#        'Sawai Madhopur', 'Vaishali', 'Karur', 'Rupnagar', 'Sabarkantha',
#        'Una', 'Bhilwara', 'Bara Banki', 'Cachar', 'Dehradun', 'Chamba',
#        'Shajapur', 'The Nilgiris', 'Wardha', 'Nabarangapur',
#        'Shaheed Bhagat Singh Nagar', 'Davangere', 'Dahod', 'Tiruppur',
#        'Vizianagaram', 'Moga', 'Rajkot', 'Hyderabad', 'Sundergarh',
#        'Kurnool', 'Warangal', 'Tirunelveli', 'South Goa', 'Anantapur',
#        'Thiruvananthapuram', 'Srikakulam', 'Nizamabad', 'Cuttack',
#        'Baran', 'Guntur', 'Mysuru', 'Purba Medinipur', 'Ernakulam',
#        'Balaghat', 'Sivaganga', 'Harda *', 'Mokokchung', 'Uttara Kannada',
#        'Perambalur', 'Udupi', 'Ananthapur', 'Coimbatore',
#        'West Singhbhum', 'Tumakuru', 'Birbhum', 'Visakhapatnam', 'Hardoi',
# ...

# %%
#remove the unwanted symbol
import re

df_copy['district'] = (
    df_copy['district']
    .astype(str)
    .str.replace('&', 'And', regex=False)
    .str.replace(r'\*+', '', regex=True)               # remove *
    .str.replace(r'\(.*?\)', '', regex=True)           # remove anything in ()
    .str.replace(r'–|−|—', '-', regex=True)            # normalize hyphens
    .str.replace(r'\s+', ' ', regex=True)              # extra spaces
    .str.strip()
    .str.title()
)

# %%
df_copy["district"].unique()
# Out:
# array(['Mahendragarh', 'Madhepura', 'Punch', 'Bhojpur', 'Madurai',
#        'Ratnagiri', 'Anand', 'Gandhinagar', 'Dhenkanal', 'Valsad',
#        'Salem', 'Hooghly', 'Paschim Medinipur', 'Wayanad',
#        'Sawai Madhopur', 'Vaishali', 'Karur', 'Rupnagar', 'Sabarkantha',
#        'Una', 'Bhilwara', 'Bara Banki', 'Cachar', 'Dehradun', 'Chamba',
#        'Shajapur', 'The Nilgiris', 'Wardha', 'Nabarangapur',
#        'Shaheed Bhagat Singh Nagar', 'Davangere', 'Dahod', 'Tiruppur',
#        'Vizianagaram', 'Moga', 'Rajkot', 'Hyderabad', 'Sundergarh',
#        'Kurnool', 'Warangal', 'Tirunelveli', 'South Goa', 'Anantapur',
#        'Thiruvananthapuram', 'Srikakulam', 'Nizamabad', 'Cuttack',
#        'Baran', 'Guntur', 'Mysuru', 'Purba Medinipur', 'Ernakulam',
#        'Balaghat', 'Sivaganga', 'Harda', 'Mokokchung', 'Uttara Kannada',
#        'Perambalur', 'Udupi', 'Ananthapur', 'Coimbatore',
#        'West Singhbhum', 'Tumakuru', 'Birbhum', 'Visakhapatnam', 'Hardoi',
# ...

# %%
district_mapping = {
    # Karnataka
    "Bangalore": "Bengaluru",
    "Bangalore Urban": "Bengaluru Urban",
    "Bangalore Rural": "Bengaluru Rural",
    "Mysore": "Mysuru",
    "Tumkur": "Tumakuru",
    "Bellary": "Ballari",
    "Belgaum": "Belagavi",
    "Gulbarga": "Kalaburagi",
    "Shimoga": "Shivamogga",

    # Telangana
    "Mahbubnagar": "Mahabubnagar",
    "Rangareddi": "Ranga Reddy",
    "K.V. Rangareddy": "Ranga Reddy",
    "K.V.Rangareddy": "Ranga Reddy",

    # Gujarat
    "Ahmadabad": "Ahmedabad",
    "Ahmed Nagar": "Ahmednagar",
    "Surendra Nagar": "Surendranagar",
    "Sabar Kantha": "Sabarkantha",

    # West Bengal
    "Coochbehar": "Cooch Behar",
    "Koch Bihar": "Cooch Behar",
    "Haora": "Howrah",
    "Hawrah": "Howrah",
    "Darjiling": "Darjeeling",
    "Burdwan": "Bardhaman",

    # Uttar Pradesh
    "Allahabad": "Prayagraj",
    "Faizabad": "Ayodhya",
    "Raebareli": "Rae Bareli",
    "Bulandshahar": "Bulandshahr",
    "Barabanki": "Bara Banki",

    # Tamil Nadu
    "Tuticorin": "Thoothukkudi",
    "Kancheepuram": "Kanchipuram",
    "Viluppuram": "Villupuram",
}

# %%
df_copy["district"] = df_copy["district"].replace(district_mapping)

# %%
bihar_district_mapping = {
    # Champaran
    "Purbi Champaran": "East Champaran",
    "Purba Champaran": "East Champaran",
    "East Champaran": "East Champaran",
    "Pashchim Champaran": "West Champaran",
    "West Champaran": "West Champaran",

    # Common spellings / variants
    "Bara Banki": "Barabanki",   # (NOTE: actually UP, remove if appears under Bihar)
    "Monghyr": "Munger",
    "Samstipur": "Samastipur",
    "Sheikpura": "Sheikhpura",
    "Bhabua": "Kaimur",
    "Kaimur": "Kaimur",
    "Kaimur (Bhabua)": "Kaimur",

    # Core Bihar districts (already correct)
    "Araria": "Araria",
    "Arwal": "Arwal",
    "Aurangabad": "Aurangabad",
    "Banka": "Banka",
    "Begusarai": "Begusarai",
    "Bhagalpur": "Bhagalpur",
    "Bhojpur": "Bhojpur",
    "Buxar": "Buxar",
    "Darbhanga": "Darbhanga",
    "Gaya": "Gaya",
    "Gopalganj": "Gopalganj",
    "Jamui": "Jamui",
    "Jehanabad": "Jehanabad",
    "Katihar": "Katihar",
    "Khagaria": "Khagaria",
    "Kishanganj": "Kishanganj",
    "Lakhisarai": "Lakhisarai",
    "Madhepura": "Madhepura",
    "Madhubani": "Madhubani",
    "Muzaffarpur": "Muzaffarpur",
    "Nalanda": "Nalanda",
    "Nawada": "Nawada",
    "Patna": "Patna",
    "Purnia": "Purnia",
    "Purnea": "Purnia",
    "Rohtas": "Rohtas",
    "Saharsa": "Saharsa",
    "Samastipur": "Samastipur",
    "Saran": "Saran",
    "Sheohar": "Sheohar",
    "Sitamarhi": "Sitamarhi",
    "Siwan": "Siwan",
    "Supaul": "Supaul",
    "Vaishali": "Vaishali",
}
df_copy["district"] = df_copy["district"].replace(bihar_district_mapping)

# %%
west_bengal_district_mapping = {
    "Coochbehar": "Cooch Behar",
    "Koch Bihar": "Cooch Behar",
    "Haora": "Howrah",
    "Hawrah": "Howrah",
    "Darjiling": "Darjeeling",
    "Burdwan": "Bardhaman",
    "Barddhaman": "Bardhaman",
    "North Twenty Four Parganas": "North 24 Parganas",
    "South Twenty Four Parganas": "South 24 Parganas",
    "Medinipur West": "Paschim Medinipur",
    "West Midnapore": "Paschim Medinipur",
    "East Midnapore": "Purba Medinipur",
    "Puruliya": "Purulia",

    # already standard
    "Alipurduar": "Alipurduar",
    "Bankura": "Bankura",
    "Birbhum": "Birbhum",
    "Dakshin Dinajpur": "Dakshin Dinajpur",
    "Hooghly": "Hooghly",
    "Howrah": "Howrah",
    "Jalpaiguri": "Jalpaiguri",
    "Jhargram": "Jhargram",
    "Kalimpong": "Kalimpong",
    "Kolkata": "Kolkata",
    "Malda": "Malda",
    "Murshidabad": "Murshidabad",
    "Nadia": "Nadia",
    "North 24 Parganas": "North 24 Parganas",
    "Paschim Bardhaman": "Paschim Bardhaman",
    "Purba Bardhaman": "Purba Bardhaman",
    "Purba Medinipur": "Purba Medinipur",
    "Purulia": "Purulia",
    "South 24 Parganas": "South 24 Parganas",
    "Uttar Dinajpur": "Uttar Dinajpur",
}
df_copy["district"] = df_copy["district"].replace(west_bengal_district_mapping)

# %%
karnataka_district_mapping = {
    "Bangalore": "Bengaluru",
    "Bangalore Urban": "Bengaluru Urban",
    "Bangalore Rural": "Bengaluru Rural",
    "Mysore": "Mysuru",
    "Tumkur": "Tumakuru",
    "Bellary": "Ballari",
    "Belgaum": "Belagavi",
    "Gulbarga": "Kalaburagi",
    "Shimoga": "Shivamogga",
    "Chickmagalur": "Chikkamagaluru",
    "Chikmagalur": "Chikkamagaluru",
    "Chamrajanagar": "Chamarajanagar",
    "Chamrajnagar": "Chamarajanagar",

    # already standard
    "Bagalkot": "Bagalkot",
    "Ballari": "Ballari",
    "Bidar": "Bidar",
    "Chitradurga": "Chitradurga",
    "Dakshina Kannada": "Dakshina Kannada",
    "Davanagere": "Davanagere",
    "Dharwad": "Dharwad",
    "Gadag": "Gadag",
    "Hassan": "Hassan",
    "Haveri": "Haveri",
    "Kodagu": "Kodagu",
    "Kolar": "Kolar",
    "Koppal": "Koppal",
    "Mandya": "Mandya",
    "Ramanagara": "Ramanagara",
    "Raichur": "Raichur",
    "Udupi": "Udupi",
    "Uttara Kannada": "Uttara Kannada",
    "Vijayanagara": "Vijayanagara",
    "Yadgir": "Yadgir",
}
df_copy["district"] = df_copy["district"].replace(karnataka_district_mapping)

# %%
uttar_pradesh_district_mapping = {
    "Allahabad": "Prayagraj",
    "Prayagraj": "Prayagraj",
    "Faizabad": "Ayodhya",
    "Ayodhya": "Ayodhya",
    "Raebareli": "Rae Bareli",
    "Bara Banki": "Barabanki",
    "Barabanki": "Barabanki",
    "Bulandshahar": "Bulandshahr",
    "Siddharth Nagar": "Siddharthnagar",
    "Sant Ravidas Nagar Bhadohi": "Bhadohi",
    "Jyotiba Phule Nagar": "Amroha",
    "Kushi Nagar": "Kushinagar",
    "Mahrajganj": "Maharajganj",

    # already standard
    "Agra": "Agra",
    "Aligarh": "Aligarh",
    "Azamgarh": "Azamgarh",
    "Bahraich": "Bahraich",
    "Ballia": "Ballia",
    "Banda": "Banda",
    "Bareilly": "Bareilly",
    "Basti": "Basti",
    "Bijnor": "Bijnor",
    "Chandauli": "Chandauli",
    "Deoria": "Deoria",
    "Etah": "Etah",
    "Etawah": "Etawah",
    "Farrukhabad": "Farrukhabad",
    "Fatehpur": "Fatehpur",
    "Ghazipur": "Ghazipur",
    "Gonda": "Gonda",
    "Gorakhpur": "Gorakhpur",
    "Hardoi": "Hardoi",
    "Hathras": "Hathras",
    "Jaunpur": "Jaunpur",
    "Jhansi": "Jhansi",
    "Kannauj": "Kannauj",
    "Kanpur Dehat": "Kanpur Dehat",
    "Kanpur Nagar": "Kanpur Nagar",
    "Kaushambi": "Kaushambi",
    "Kheri": "Kheri",
    "Lalitpur": "Lalitpur",
    "Lucknow": "Lucknow",
    "Mau": "Mau",
    "Meerut": "Meerut",
    "Mirzapur": "Mirzapur",
    "Moradabad": "Moradabad",
    "Muzaffarnagar": "Muzaffarnagar",
    "Pilibhit": "Pilibhit",
    "Rampur": "Rampur",
    "Saharanpur": "Saharanpur",
    "Shahjahanpur": "Shahjahanpur",
    "Shamli": "Shamli",
    "Sitapur": "Sitapur",
    "Sonbhadra": "Sonbhadra",
    "Sultanpur": "Sultanpur",
    "Unnao": "Unnao",
    "Varanasi": "Varanasi",
}
df_copy["district"] = df_copy["district"].replace(uttar_pradesh_district_mapping)

# %%
maharashtra_district_mapping = {
    "Ahmed Nagar": "Ahmednagar",
    "Ahmadnagar": "Ahmednagar",
    "Aurangabad": "Chhatrapati Sambhajinagar",
    "Chatrapati Sambhaji Nagar": "Chhatrapati Sambhajinagar",
    "Osmanabad": "Dharashiv",
    "Bid": "Beed",
    "Buldana": "Buldhana",
    "Gondia": "Gondiya",

    # already standard / common
    "Akola": "Akola",
    "Amravati": "Amravati",
    "Beed": "Beed",
    "Bhandara": "Bhandara",
    "Chandrapur": "Chandrapur",
    "Dhule": "Dhule",
    "Gadchiroli": "Gadchiroli",
    "Hingoli": "Hingoli",
    "Jalgaon": "Jalgaon",
    "Jalna": "Jalna",
    "Kolhapur": "Kolhapur",
    "Latur": "Latur",
    "Mumbai": "Mumbai",
    "Mumbai City": "Mumbai City",
    "Mumbai Suburban": "Mumbai Suburban",
    "Nagpur": "Nagpur",
    "Nanded": "Nanded",
    "Nandurbar": "Nandurbar",
    "Nashik": "Nashik",
    "Palghar": "Palghar",
    "Parbhani": "Parbhani",
    "Pune": "Pune",
    "Raigad": "Raigad",
    "Ratnagiri": "Ratnagiri",
    "Sangli": "Sangli",
    "Satara": "Satara",
    "Sindhudurg": "Sindhudurg",
    "Solapur": "Solapur",
    "Thane": "Thane",
    "Wardha": "Wardha",
    "Washim": "Washim",
    "Yavatmal": "Yavatmal",
}
df_copy["district"] = df_copy["district"].replace(maharashtra_district_mapping)

# %%
tamil_nadu_district_mapping = {
    "Tuticorin": "Thoothukkudi",
    "Viluppuram": "Villupuram",
    "Kancheepuram": "Kanchipuram",
    "Kanniyakumari": "Kanyakumari",

    # already standard / common
    "Ariyalur": "Ariyalur",
    "Chengalpattu": "Chengalpattu",
    "Chennai": "Chennai",
    "Coimbatore": "Coimbatore",
    "Cuddalore": "Cuddalore",
    "Dharmapuri": "Dharmapuri",
    "Dindigul": "Dindigul",
    "Erode": "Erode",
    "Kallakurichi": "Kallakurichi",
    "Karur": "Karur",
    "Krishnagiri": "Krishnagiri",
    "Madurai": "Madurai",
    "Mayiladuthurai": "Mayiladuthurai",
    "Nagapattinam": "Nagapattinam",
    "Namakkal": "Namakkal",
    "Perambalur": "Perambalur",
    "Pudukkottai": "Pudukkottai",
    "Ramanathapuram": "Ramanathapuram",
    "Ranipet": "Ranipet",
    "Salem": "Salem",
    "Sivaganga": "Sivaganga",
    "Tenkasi": "Tenkasi",
    "Thanjavur": "Thanjavur",
    "The Nilgiris": "The Nilgiris",
    "Theni": "Theni",
    "Thiruvallur": "Thiruvallur",
    "Thiruvarur": "Thiruvarur",
    "Tiruchirappalli": "Tiruchirappalli",
    "Tirunelveli": "Tirunelveli",
    "Tirupattur": "Tirupattur",
    "Tiruppur": "Tiruppur",
    "Tiruvannamalai": "Tiruvannamalai",
    "Vellore": "Vellore",
    "Virudhunagar": "Virudhunagar",
}
df_copy["district"] = df_copy["district"].replace(tamil_nadu_district_mapping)

# %%
gujarat_district_mapping = {
    "Ahmadabad": "Ahmedabad",
    "Ahmed Nagar": "Ahmednagar",   # if appears (otherwise ignore)
    "Surendra Nagar": "Surendranagar",
    "Panch Mahals": "Panchmahals",
    "Sabar Kantha": "Sabarkantha",
    "Kachchh": "Kutch",
    "Dohad": "Dahod",

    # already standard / common
    "Amreli": "Amreli",
    "Anand": "Anand",
    "Arvalli": "Aravalli",
    "Banaskantha": "Banaskantha",
    "Bharuch": "Bharuch",
    "Bhavnagar": "Bhavnagar",
    "Botad": "Botad",
    "Chhotaudepur": "Chhotaudepur",
    "Devbhumi Dwarka": "Devbhumi Dwarka",
    "Gandhinagar": "Gandhinagar",
    "Gir Somnath": "Gir Somnath",
    "Jamnagar": "Jamnagar",
    "Junagadh": "Junagadh",
    "Kheda": "Kheda",
    "Mahesana": "Mehsana",
    "Mahisagar": "Mahisagar",
    "Morbi": "Morbi",
    "Narmada": "Narmada",
    "Navsari": "Navsari",
    "Patan": "Patan",
    "Porbandar": "Porbandar",
    "Rajkot": "Rajkot",
    "Surat": "Surat",
    "Tapi": "Tapi",
    "Vadodara": "Vadodara",
    "Valsad": "Valsad",
}
df_copy["district"] = df_copy["district"].replace(gujarat_district_mapping)

# %%
assam_district_mapping = {
    "North Cachar Hills": "Dima Hasao",
    "Sibsagar": "Sivasagar",

    # already standard / common
    "Baksa": "Baksa",
    "Barpeta": "Barpeta",
    "Biswanath": "Biswanath",
    "Bongaigaon": "Bongaigaon",
    "Cachar": "Cachar",
    "Charaideo": "Charaideo",
    "Chirang": "Chirang",
    "Darrang": "Darrang",
    "Dhemaji": "Dhemaji",
    "Dhubri": "Dhubri",
    "Dibrugarh": "Dibrugarh",
    "Goalpara": "Goalpara",
    "Golaghat": "Golaghat",
    "Hailakandi": "Hailakandi",
    "Hojai": "Hojai",
    "Jorhat": "Jorhat",
    "Kamrup": "Kamrup",
    "Kamrup Metro": "Kamrup Metropolitan",
    "Karimganj": "Karimganj",
    "Kokrajhar": "Kokrajhar",
    "Lakhimpur": "Lakhimpur",
    "Majuli": "Majuli",
    "Marigaon": "Morigaon",
    "Nagaon": "Nagaon",
    "Nalbari": "Nalbari",
    "Sonitpur": "Sonitpur",
    "South Salmara Mankachar": "South Salmara-Mankachar",
    "Tinsukia": "Tinsukia",
    "Udalguri": "Udalguri",
}
df_copy["district"] = df_copy["district"].replace(assam_district_mapping)

# %%
telangana_district_mapping = {
    "K.V. Rangareddy": "Ranga Reddy",
    "K.V.Rangareddy": "Ranga Reddy",
    "Rangareddi": "Ranga Reddy",
    "Mahbub Nagar": "Mahabubnagar",
    "Mahbubnagar": "Mahabubnagar",

    # already standard / common
    "Adilabad": "Adilabad",
    "Bhadradri Kothagudem": "Bhadradri Kothagudem",
    "Hanumakonda": "Hanumakonda",
    "Hyderabad": "Hyderabad",
    "Jagitial": "Jagtial",
    "Jangaon": "Jangaon",
    "Jayashankar Bhupalpally": "Jayashankar Bhupalpally",
    "Jogulamba Gadwal": "Jogulamba Gadwal",
    "Kamareddy": "Kamareddy",
    "Karimnagar": "Karimnagar",
    "Khammam": "Khammam",
    "Komaram Bheem": "Komaram Bheem",
    "Medak": "Medak",
    "Medchal-Malkajgiri": "Medchal-Malkajgiri",
    "Mulugu": "Mulugu",
    "Nagarkurnool": "Nagarkurnool",
    "Nalgonda": "Nalgonda",
    "Narayanpet": "Narayanpet",
    "Nirmal": "Nirmal",
    "Nizamabad": "Nizamabad",
    "Peddapalli": "Peddapalli",
    "Rajanna Sircilla": "Rajanna Sircilla",
    "Sangareddy": "Sangareddy",
    "Siddipet": "Siddipet",
    "Suryapet": "Suryapet",
    "Vikarabad": "Vikarabad",
    "Wanaparthy": "Wanaparthy",
    "Warangal Rural": "Warangal Rural",
    "Warangal Urban": "Warangal Urban",
    "Yadadri": "Yadadri Bhuvanagiri",
}
df_copy["district"] = df_copy["district"].replace(telangana_district_mapping)

# %%
rajasthan_district_mapping = {
    "Dhaulpur": "Dholpur",
    "Chittaurgarh": "Chittorgarh",

    # already standard / common
    "Ajmer": "Ajmer",
    "Alwar": "Alwar",
    "Banswara": "Banswara",
    "Baran": "Baran",
    "Barmer": "Barmer",
    "Bharatpur": "Bharatpur",
    "Bhilwara": "Bhilwara",
    "Bikaner": "Bikaner",
    "Bundi": "Bundi",
    "Churu": "Churu",
    "Dausa": "Dausa",
    "Dungarpur": "Dungarpur",
    "Ganganagar": "Ganganagar",
    "Hanumangarh": "Hanumangarh",
    "Jaipur": "Jaipur",
    "Jaisalmer": "Jaisalmer",
    "Jalore": "Jalore",
    "Jhalawar": "Jhalawar",
    "Jhunjhunu": "Jhunjhunu",
    "Jodhpur": "Jodhpur",
    "Karauli": "Karauli",
    "Kota": "Kota",
    "Nagaur": "Nagaur",
    "Pali": "Pali",
    "Pratapgarh": "Pratapgarh",
    "Rajsamand": "Rajsamand",
    "Sawai Madhopur": "Sawai Madhopur",
    "Sikar": "Sikar",
    "Sirohi": "Sirohi",
    "Tonk": "Tonk",
    "Udaipur": "Udaipur",
}
df_copy["district"] = df_copy["district"].replace(rajasthan_district_mapping)

# %%
madhya_pradesh_district_mapping = {
    "Hoshangabad": "Narmadapuram",
    "East Nimar": "Khandwa",
    "West Nimar": "Khargone",

    # already standard / common
    "Agar Malwa": "Agar Malwa",
    "Alirajpur": "Alirajpur",
    "Anuppur": "Anuppur",
    "Ashok Nagar": "Ashok Nagar",
    "Balaghat": "Balaghat",
    "Barwani": "Barwani",
    "Betul": "Betul",
    "Bhind": "Bhind",
    "Bhopal": "Bhopal",
    "Burhanpur": "Burhanpur",
    "Chhatarpur": "Chhatarpur",
    "Chhindwara": "Chhindwara",
    "Damoh": "Damoh",
    "Datia": "Datia",
    "Dewas": "Dewas",
    "Dhar": "Dhar",
    "Dindori": "Dindori",
    "Guna": "Guna",
    "Gwalior": "Gwalior",
    "Harda": "Harda",
    "Indore": "Indore",
    "Jabalpur": "Jabalpur",
    "Jhabua": "Jhabua",
    "Katni": "Katni",
    "Mandla": "Mandla",
    "Mandsaur": "Mandsaur",
    "Morena": "Morena",
    "Narsinghpur": "Narsinghpur",
    "Neemuch": "Neemuch",
    "Niwari": "Niwari",
    "Panna": "Panna",
    "Raisen": "Raisen",
    "Rajgarh": "Rajgarh",
    "Ratlam": "Ratlam",
    "Rewa": "Rewa",
    "Sagar": "Sagar",
    "Satna": "Satna",
    "Sehore": "Sehore",
    "Seoni": "Seoni",
    "Shahdol": "Shahdol",
    "Shajapur": "Shajapur",
    "Sheopur": "Sheopur",
    "Shivpuri": "Shivpuri",
    "Sidhi": "Sidhi",
    "Singrauli": "Singrauli",
    "Tikamgarh": "Tikamgarh",
    "Ujjain": "Ujjain",
    "Vidisha": "Vidisha",
}
df_copy["district"] = df_copy["district"].replace(madhya_pradesh_district_mapping)

# %%
odisha_district_mapping = {
    "Anugul": "Angul",
    "Sonapur": "Subarnapur",

    # already standard / common
    "Angul": "Angul",
    "Balangir": "Balangir",
    "Baleswar": "Balasore",
    "Bargarh": "Bargarh",
    "Bhadrak": "Bhadrak",
    "Boudh": "Boudh",
    "Cuttack": "Cuttack",
    "Debagarh": "Debagarh",
    "Dhenkanal": "Dhenkanal",
    "Gajapati": "Gajapati",
    "Ganjam": "Ganjam",
    "Jagatsinghapur": "Jagatsinghapur",
    "Jajpur": "Jajpur",
    "Jharsuguda": "Jharsuguda",
    "Kalahandi": "Kalahandi",
    "Kandhamal": "Kandhamal",
    "Kendrapara": "Kendrapara",
    "Kendujhar": "Kendujhar",
    "Khordha": "Khordha",
    "Koraput": "Koraput",
    "Malkangiri": "Malkangiri",
    "Mayurbhanj": "Mayurbhanj",
    "Nabarangapur": "Nabarangapur",
    "Nayagarh": "Nayagarh",
    "Nuapada": "Nuapada",
    "Puri": "Puri",
    "Rayagada": "Rayagada",
    "Sambalpur": "Sambalpur",
    "Sundargarh": "Sundargarh",
}
df_copy["district"] = df_copy["district"].replace(odisha_district_mapping)

# %%
punjab_district_mapping = {
    "Firozpur": "Ferozepur",
    "Muktsar": "Sri Muktsar Sahib",
    "Sas Nagar": "S.A.S Nagar",
    "S.A.S Nagar(Mohali)": "S.A.S Nagar",

    # already standard / common
    "Amritsar": "Amritsar",
    "Barnala": "Barnala",
    "Bathinda": "Bathinda",
    "Faridkot": "Faridkot",
    "Fatehgarh Sahib": "Fatehgarh Sahib",
    "Gurdaspur": "Gurdaspur",
    "Hoshiarpur": "Hoshiarpur",
    "Jalandhar": "Jalandhar",
    "Kapurthala": "Kapurthala",
    "Ludhiana": "Ludhiana",
    "Malerkotla": "Malerkotla",
    "Mansa": "Mansa",
    "Pathankot": "Pathankot",
    "Patiala": "Patiala",
    "Rupnagar": "Rupnagar",
    "Sangrur": "Sangrur",
    "Tarn Taran": "Tarn Taran",
}
df_copy["district"] = df_copy["district"].replace(odisha_district_mapping)

# %%
kerala_district_mapping = {
    "Kasargod": "Kasaragod",

    # already standard / common
    "Alappuzha": "Alappuzha",
    "Ernakulam": "Ernakulam",
    "Idukki": "Idukki",
    "Kannur": "Kannur",
    "Kasaragod": "Kasaragod",
    "Kollam": "Kollam",
    "Kottayam": "Kottayam",
    "Kozhikode": "Kozhikode",
    "Malappuram": "Malappuram",
    "Palakkad": "Palakkad",
    "Pathanamthitta": "Pathanamthitta",
    "Thiruvananthapuram": "Thiruvananthapuram",
    "Thrissur": "Thrissur",
    "Wayanad": "Wayanad",
}
df_copy["district"] = df_copy["district"].replace(kerala_district_mapping)

# %%
haryana_district_mapping = {
    # spelling / format fixes
    "Yamunanagar": "Yamuna Nagar",

    # already standard / common
    "Ambala": "Ambala",
    "Bhiwani": "Bhiwani",
    "Charkhi Dadri": "Charkhi Dadri",
    "Faridabad": "Faridabad",
    "Fatehabad": "Fatehabad",
    "Gurgaon": "Gurugram",
    "Gurugram": "Gurugram",
    "Hisar": "Hisar",
    "Jhajjar": "Jhajjar",
    "Jind": "Jind",
    "Kaithal": "Kaithal",
    "Karnal": "Karnal",
    "Kurukshetra": "Kurukshetra",
    "Mahendragarh": "Mahendragarh",
    "Nuh": "Nuh",
    "Palwal": "Palwal",
    "Panchkula": "Panchkula",
    "Panipat": "Panipat",
    "Rewari": "Rewari",
    "Rohtak": "Rohtak",
    "Sirsa": "Sirsa",
    "Sonipat": "Sonipat",
}
df_copy["district"] = df_copy["district"].replace(haryana_district_mapping)

# %%
jharkhand_district_mapping = {
    # spelling / legacy fixes
    "Hazaribag": "Hazaribagh",
    "Kodarma": "Koderma",
    "Pakaur": "Pakur",
    "Sahebganj": "Sahibganj",
    "Purbi Singhbhum": "East Singhbhum",
    "Pashchimi Singhbhum": "West Singhbhum",

    # already standard / common
    "Bokaro": "Bokaro",
    "Chatra": "Chatra",
    "Deoghar": "Deoghar",
    "Dhanbad": "Dhanbad",
    "Dumka": "Dumka",
    "Garhwa": "Garhwa",
    "Giridih": "Giridih",
    "Godda": "Godda",
    "Gumla": "Gumla",
    "Jamtara": "Jamtara",
    "Khunti": "Khunti",
    "Latehar": "Latehar",
    "Lohardaga": "Lohardaga",
    "Pakur": "Pakur",
    "Palamu": "Palamu",
    "Ramgarh": "Ramgarh",
    "Ranchi": "Ranchi",
    "Saraikela-Kharsawan": "Seraikela-Kharsawan",
    "Simdega": "Simdega",
}
df_copy["district"] = df_copy["district"].replace(jharkhand_district_mapping)

# %%
chhattisgarh_district_mapping = {
    # merged / renamed districts
    "Dakshin Bastar Dantewada": "Dantewada",

    # already standard / common
    "Balod": "Balod",
    "Baloda Bazar": "Baloda Bazar",
    "Bastar": "Bastar",
    "Bemetara": "Bemetara",
    "Bijapur": "Bijapur",
    "Bilaspur": "Bilaspur",
    "Dantewada": "Dantewada",
    "Dhamtari": "Dhamtari",
    "Durg": "Durg",
    "Gariyaband": "Gariyaband",
    "Janjgir-Champa": "Janjgir-Champa",
    "Jashpur": "Jashpur",
    "Kabeerdham": "Kabirdham",
    "Kanker": "Kanker",
    "Kondagaon": "Kondagaon",
    "Korba": "Korba",
    "Mahasamund": "Mahasamund",
    "Mungeli": "Mungeli",
    "Narayanpur": "Narayanpur",
    "Raigarh": "Raigarh",
    "Raipur": "Raipur",
    "Rajnandgaon": "Rajnandgaon",
    "Sukma": "Sukma",
    "Surajpur": "Surajpur",
    "Surguja": "Surguja",
}
df_copy["district"] = df_copy["district"].replace(chhattisgarh_district_mapping)

# %%
delhi_district_mapping = {
    # normalize all to official district names
    "Central Delhi": "Central Delhi",
    "East Delhi": "East Delhi",
    "New Delhi": "New Delhi",
    "North Delhi": "North Delhi",
    "North East Delhi": "North East Delhi",
    "North West Delhi": "North West Delhi",
    "Shahdara": "Shahdara",
    "South Delhi": "South Delhi",
    "South East Delhi": "South East Delhi",
    "South West Delhi": "South West Delhi",
    "West Delhi": "West Delhi",
}
df_copy["district"] = df_copy["district"].replace(delhi_district_mapping)

# %%
uts_district_mapping = {
    # Chandigarh
    "Chandigarh": "Chandigarh",

    # Dadra & Nagar Haveli and Daman & Diu
    "Dadra And Nagar Haveli": "Dadra And Nagar Haveli And Daman And Diu",
    "Daman": "Dadra And Nagar Haveli And Daman And Diu",
    "Diu": "Dadra And Nagar Haveli And Daman And Diu",

    # Jammu & Kashmir / Ladakh
    "Rajauri": "Rajouri",
    "Baramula": "Baramulla",

    # Andaman & Nicobar
    "Andamans": "Andaman And Nicobar Islands",
    "Nicobar": "Nicobar",
    "South Andaman": "South Andaman",
}
df_copy["district"] = df_copy["district"].replace(uts_district_mapping)

# %%
assam_district_mapping = {
    "North Cachar Hills": "Dima Hasao",
    "Sibsagar": "Sivasagar",
    "Marigaon": "Morigaon",
    "Kamrup Metro": "Kamrup Metropolitan",
    "South Salmara Mankachar": "South Salmara-Mankachar",

    # already standard
    "Baksa": "Baksa",
    "Barpeta": "Barpeta",
    "Biswanath": "Biswanath",
    "Bongaigaon": "Bongaigaon",
    "Cachar": "Cachar",
    "Charaideo": "Charaideo",
    "Chirang": "Chirang",
    "Darrang": "Darrang",
    "Dhemaji": "Dhemaji",
    "Dhubri": "Dhubri",
    "Dibrugarh": "Dibrugarh",
    "Goalpara": "Goalpara",
    "Golaghat": "Golaghat",
    "Hailakandi": "Hailakandi",
    "Hojai": "Hojai",
    "Jorhat": "Jorhat",
    "Kamrup": "Kamrup",
    "Karimganj": "Karimganj",
    "Kokrajhar": "Kokrajhar",
    "Lakhimpur": "Lakhimpur",
    "Majuli": "Majuli",
    "Nagaon": "Nagaon",
    "Nalbari": "Nalbari",
    "Sonitpur": "Sonitpur",
    "Tinsukia": "Tinsukia",
    "Udalguri": "Udalguri",
}
df_copy["district"] = df_copy["district"].replace(assam_district_mapping)

# %%
meghalaya_district_mapping = {
    "East Khasi Hills": "East Khasi Hills",
    "West Khasi Hills": "West Khasi Hills",
    "South West Khasi Hills": "South West Khasi Hills",
    "Eastern West Khasi Hills": "Eastern West Khasi Hills",
    "Ri Bhoi": "Ri-Bhoi",
    "West Jaintia Hills": "West Jaintia Hills",
    "East Jaintia Hills": "East Jaintia Hills",
    "West Garo Hills": "West Garo Hills",
    "South Garo Hills": "South Garo Hills",
    "North Garo Hills": "North Garo Hills",
    "South West Garo Hills": "South West Garo Hills",
    "East Garo Hills": "East Garo Hills",
}
df_copy["district"] = df_copy["district"].replace(meghalaya_district_mapping)

# %%
tripura_district_mapping = {
    "West Tripura": "West Tripura",
    "South Tripura": "South Tripura",
    "North Tripura": "North Tripura",
    "Dhalai": "Dhalai",
    "Gomati": "Gomati",
    "Sepahijala": "Sepahijala",
    "Khowai": "Khowai",
    "Unakoti": "Unakoti",
}
df_copy["district"] = df_copy["district"].replace(tripura_district_mapping)

# %%
manipur_district_mapping = {
    "Imphal East": "Imphal East",
    "Imphal West": "Imphal West",
    "Bishnupur": "Bishnupur",
    "Chandel": "Chandel",
    "Churachandpur": "Churachandpur",
    "Senapati": "Senapati",
    "Tamenglong": "Tamenglong",
    "Thoubal": "Thoubal",
    "Ukhrul": "Ukhrul",
    "Jiribam": "Jiribam",
    "Kakching": "Kakching",
    "Kamjong": "Kamjong",
    "Noney": "Noney",
    "Pherzawl": "Pherzawl",
    "Tengnoupal": "Tengnoupal",
}
df_copy["district"] = df_copy["district"].replace(manipur_district_mapping)

# %%
mizoram_district_mapping = {
    "Aizawl": "Aizawl",
    "Lunglei": "Lunglei",
    "Lawngtlai": "Lawngtlai",
    "Saiha": "Saiha",
    "Champhai": "Champhai",
    "Kolasib": "Kolasib",
    "Serchhip": "Serchhip",
    "Mamit": "Mamit",
    "Hnahthial": "Hnahthial",
    "Saitual": "Saitual",
}
df_copy["district"] = df_copy["district"].replace(mizoram_district_mapping)

# %%
nagaland_district_mapping = {
    "Kohima": "Kohima",
    "Dimapur": "Dimapur",
    "Mokokchung": "Mokokchung",
    "Tuensang": "Tuensang",
    "Zunheboto": "Zunheboto",
    "Wokha": "Wokha",
    "Mon": "Mon",
    "Peren": "Peren",
    "Longleng": "Longleng",
    "Kiphire": "Kiphire",
    "Noklak": "Noklak",
}
df_copy["district"] = df_copy["district"].replace(nagaland_district_mapping)

# %%
arunachal_pradesh_district_mapping = {
    "Tawang": "Tawang",
    "West Kameng": "West Kameng",
    "East Kameng": "East Kameng",
    "Papum Pare": "Papum Pare",
    "Kurung Kumey": "Kurung Kumey",
    "Lower Subansiri": "Lower Subansiri",
    "Upper Subansiri": "Upper Subansiri",
    "West Siang": "West Siang",
    "East Siang": "East Siang",
    "Upper Siang": "Upper Siang",
    "Lower Dibang Valley": "Lower Dibang Valley",
    "Dibang Valley": "Dibang Valley",
    "Anjaw": "Anjaw",
    "Changlang": "Changlang",
    "Tirap": "Tirap",
    "Namsai": "Namsai",
    "Siang": "Siang",
    "Shi-Yomi": "Shi-Yomi",
    "Kamle": "Kamle",
    "Kra Daadi": "Kra Daadi",
    "Leparada": "Leparada",
    "Pakke Kessang": "Pakke Kessang",
}
df_copy["district"] = df_copy["district"].replace(arunachal_pradesh_district_mapping)

# %%
jammu_kashmir_district_mapping = {
    "Anantnag": "Anantnag",
    "Bandipore": "Bandipora",
    "Baramula": "Baramulla",
    "Budgam": "Budgam",
    "Badgam": "Budgam",
    "Doda": "Doda",
    "Ganderbal": "Ganderbal",
    "Jammu": "Jammu",
    "Kathua": "Kathua",
    "Kishtwar": "Kishtwar",
    "Kulgam": "Kulgam",
    "Kupwara": "Kupwara",
    "Pulwama": "Pulwama",
    "Rajauri": "Rajouri",
    "Ramban": "Ramban",
    "Reasi": "Reasi",
    "Samba": "Samba",
    "Shopian": "Shopian",
    "Shupiyan": "Shopian",
    "Srinagar": "Srinagar",
    "Udhampur": "Udhampur",
}
df_copy["district"] = df_copy["district"].replace(jammu_kashmir_district_mapping)

# %%
ladakh_district_mapping = {
    "Leh": "Leh",
    "Leh (Ladakh)": "Leh",
    "Kargil": "Kargil",
}
df_copy["district"] = df_copy["district"].replace(ladakh_district_mapping)

# %%
other_uts_district_mapping = {
    # Chandigarh
    "Chandigarh": "Chandigarh",

    # Dadra & Nagar Haveli and Daman & Diu
    "Dadra And Nagar Haveli": "Dadra And Nagar Haveli And Daman And Diu",
    "Daman": "Dadra And Nagar Haveli And Daman And Diu",
    "Diu": "Dadra And Nagar Haveli And Daman And Diu",

    # Andaman & Nicobar Islands
    "Andamans": "Andaman And Nicobar Islands",
    "North And Middle Andaman": "North And Middle Andaman",
    "South Andaman": "South Andaman",
    "Nicobar": "Nicobar",

    # Puducherry
    "Puducherry": "Puducherry",
    "Pondicherry": "Puducherry",
    "Karaikal": "Karaikal",
    "Yanam": "Yanam",
    "Mahe": "Mahe",

    # Lakshadweepdistrict_corrections = {
    # Typos & Encoding Fixes
    'Medchalâ\x88\x92Malkajgiri': 'Medchal-Malkajgiri',
    'Medchal?Malkajgiri': 'Medchal-Malkajgiri',
    'Yadadri.': 'Yadadri Bhuvanagiri',
    'Hooghiy': 'Hooghly',
    'Janjgir - Champa': 'Janjgir-Champa',
    'South 24 Pargana': 'South 24 Parganas',
    'Dist : Thane': 'Thane',

    # Standardization (Aliases)
    'West Medinipur': 'Paschim Medinipur',
    'East Midnapur': 'Purba Medinipur',
    'Ahilyanagar': 'Ahmednagar',
    'Dharashiv': 'Osmanabad',
    'Chhatrapati Sambhajinagar': 'Aurangabad',
    'Sas Nagar': 'S.A.S. Nagar',

    # Invalid / Garbage Entries (Mapped to 'Unknown')
    '5Th Cross': 'Unknown',
    'Near University Thana': 'Unknown',
    'Near Meera Hospital': 'Unknown',
    'Near Uday Nagar Nit Garden': 'Unknown',
    'Near Dhyana Ashram': 'Unknown',
    'Kadiri Road': 'Unknown',
    'Idpl Colony': 'Unknown',
    'Naihati Anandabazar': 'North 24 Parganas',
    'Bally Jagachha': 'Howrah',
    'Domjur': 'Howrah',
    'Mohali': 'S.A.S. Nagar',
    'Poonch': 'Punch',
    'Bandipur': 'Bandipora',
    'Tiruvarur': 'Thiruvarur',
    'Anugal': 'Angul',
    'Nicobars': 'Nicobar',
    'South Dumdum': 'North 24 Parganas',
    'Balianta': 'Khordha',
    'Bicholim': 'North Goa',
    'Tiswadi': 'North Goa',
    'Bardez': 'North Goa',
    # Odisha Fixes
    'Balasore': 'Baleshwar',
    'Jajapur': 'Jajpur',
    'Jagatsinghapur': 'Jagatsinghpur',
    'Baudh': 'Boudh',
    'Khorda': 'Khordha',

    # West Bengal Naming Fixes
    'North Dinajpur': 'Uttar Dinajpur',
    'South Dinajpur': 'Dakshin Dinajpur',
    'West Medinipur': 'Paschim Medinipur',
    'East Midnapur': 'Purba Medinipur',
    'Maldah': 'Malda',
    'Hugli': 'Hooghly',
    'South 24 Pargana': 'South 24 Parganas',

    # Other Spelling Fixes
    'Baudh': 'Boudh',               # Odisha
    'Khorda': 'Khordha',             # Odisha
    'Palamau': 'Palamu',             # Jharkhand
    'Mahabub Nagar': 'Mahabubnagar', # Telangana
    'Karim Nagar': 'Karimnagar',     # Telangana
    'Janjgir Champa': 'Janjgir-Champa', # Chhattisgarh
    'Lahaul And Spiti': 'Lahul And Spiti', # Himachal
    'S.A.S Nagar': 'S.A.S. Nagar',   # Punjab
    'Davanagere': 'Davangere',       # Karnataka
    'Tirupathur': 'Tirupattur',      # Tamil Nadu
    'Banas Kantha': 'Banaskantha',   # Gujarat
    'Jalore': 'Jalor',               # Rajasthan
    'Tamulpur District': 'Tamulpur'  # Assam
}

df_copy["district"] = df_copy["district"].replace(other_uts_district_mapping)

# %%
other_uts_district_mapping = {
    # Chandigarh
    "Chandigarh": "Chandigarh",

    # Dadra & Nagar Haveli and Daman & Diu
    "Dadra And Nagar Haveli": "Dadra And Nagar Haveli And Daman And Diu",
    "Daman": "Dadra And Nagar Haveli And Daman And Diu",
    "Diu": "Dadra And Nagar Haveli And Daman And Diu",

    # Andaman & Nicobar Islands
    "Andamans": "Andaman And Nicobar Islands",
    "North And Middle Andaman": "North And Middle Andaman",
    "South Andaman": "South Andaman",
    "Nicobar": "Nicobar",

    # Puducherry
    "Puducherry": "Puducherry",
    "Pondicherry": "Puducherry",
    "Karaikal": "Karaikal",
    "Yanam": "Yanam",
    "Mahe": "Mahe",

    # Lakshadweepdistrict_corrections = {
    # Typos & Encoding Fixes
    'Medchalâ\x88\x92Malkajgiri': 'Medchal-Malkajgiri',
    'Medchal?Malkajgiri': 'Medchal-Malkajgiri',
    'Yadadri.': 'Yadadri Bhuvanagiri',
    'Hooghiy': 'Hooghly',
    'Janjgir - Champa': 'Janjgir-Champa',
    'South 24 Pargana': 'South 24 Parganas',
    'Dist : Thane': 'Thane',

    # Standardization (Aliases)
    'West Medinipur': 'Paschim Medinipur',
    'East Midnapur': 'Purba Medinipur',
    'Ahilyanagar': 'Ahmednagar',
    'Dharashiv': 'Osmanabad',
    'Chhatrapati Sambhajinagar': 'Aurangabad',
    'Sas Nagar': 'S.A.S. Nagar',

    # Invalid / Garbage Entries (Mapped to 'Unknown')
    '5Th Cross': 'Unknown',
    'Near University Thana': 'Unknown',
    'Near Meera Hospital': 'Unknown',
    'Near Uday Nagar Nit Garden': 'Unknown',
    'Near Dhyana Ashram': 'Unknown',
    'Kadiri Road': 'Unknown',
    'Idpl Colony': 'Unknown',
    'Naihati Anandabazar': 'North 24 Parganas',
    'Bally Jagachha': 'Howrah',
    'Domjur': 'Howrah',
    'Mohali': 'S.A.S. Nagar',
    'Poonch': 'Punch',
    'Bandipur': 'Bandipora',
    'Tiruvarur': 'Thiruvarur',
    'Anugal': 'Angul',
    'Nicobars': 'Nicobar',
    'South Dumdum': 'North 24 Parganas',
    'Balianta': 'Khordha',
    'Bicholim': 'North Goa',
    'Tiswadi': 'North Goa',
    'Bardez': 'North Goa',
    # Odisha Fixes
    'Balasore': 'Baleshwar',
    'Jajapur': 'Jajpur',
    'Jagatsinghapur': 'Jagatsinghpur',
    'Baudh': 'Boudh',
    'Khorda': 'Khordha',

    # West Bengal Naming Fixes
    'North Dinajpur': 'Uttar Dinajpur',
    'South Dinajpur': 'Dakshin Dinajpur',
    'West Medinipur': 'Paschim Medinipur',
    'East Midnapur': 'Purba Medinipur',
    'Maldah': 'Malda',
    'Hugli': 'Hooghly',
    'South 24 Pargana': 'South 24 Parganas',

    # Other Spelling Fixes
    'Baudh': 'Boudh',               # Odisha
    'Khorda': 'Khordha',             # Odisha
    'Palamau': 'Palamu',             # Jharkhand
    'Mahabub Nagar': 'Mahabubnagar', # Telangana
    'Karim Nagar': 'Karimnagar',     # Telangana
    'Janjgir Champa': 'Janjgir-Champa', # Chhattisgarh
    'Lahaul And Spiti': 'Lahul And Spiti', # Himachal
    'S.A.S Nagar': 'S.A.S. Nagar',   # Punjab
    'Davanagere': 'Davangere',       # Karnataka
    'Tirupathur': 'Tirupattur',      # Tamil Nadu
    'Banas Kantha': 'Banaskantha',   # Gujarat
    'Jalore': 'Jalor',               # Rajasthan
    'Tamulpur District': 'Tamulpur'  # Assam
}

df_copy["district"] = df_copy["district"].replace(other_uts_district_mapping)

# %%
df_copy.district.nunique()
# Out:
# 804

# %%
state_districts = df_copy.groupby("state")["district"].unique().reset_index()

# %%
df_copy.to_csv("biomatric_cleaned_dataset.csv", index=False)

# %%
# !dir
