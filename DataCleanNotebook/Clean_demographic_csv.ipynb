# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("api_data_aadhar_demographic/api_data_aadhar_demographic/api_data_aadhar_demographic_0_500000.csv")
df2 = pd.read_csv("api_data_aadhar_demographic/api_data_aadhar_demographic/api_data_aadhar_demographic_500000_1000000.csv")
df3 = pd.read_csv("api_data_aadhar_demographic/api_data_aadhar_demographic/api_data_aadhar_demographic_1000000_1500000.csv")
df4 = pd.read_csv("api_data_aadhar_demographic/api_data_aadhar_demographic/api_data_aadhar_demographic_1500000_2000000.csv")
df5 = pd.read_csv("api_data_aadhar_demographic/api_data_aadhar_demographic/api_data_aadhar_demographic_2000000_2071700.csv")
# df2 = pd.read_csv("api_data_aadhar_enrolment/api_data_aadhar_enrolment/api_data_aadhar_enrolment_500000_1000000.csv")
# df3 = pd.read_csv("api_data_aadhar_enrolment/api_data_aadhar_enrolment/api_data_aadhar_enrolment_1000000_1006029.csv")

# %%
df = pd.concat([df1,df2,df3,df4,df5],axis=0, ignore_index=True)

# %%
df.head(10)
# Out:
#          date           state           district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh          Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh           Chittoor   517132             22
# 2  01-03-2025         Gujarat             Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh         Srikakulam   532484             24
# 4  01-03-2025       Rajasthan            Udaipur   313801             45
# 5  01-03-2025       Rajasthan              Sikar   332028             28
# 6  01-03-2025       Karnataka           Tumakuru   572201             88
# 7  01-03-2025   Uttar Pradesh          Gorakhpur   273211             61
# 8  01-03-2025  Andhra Pradesh            Kurnool   518313             83
# 9  01-03-2025     West Bengal  Paschim Medinipur   721148             13
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785
# 5           285
# 6           332
# 7           836
# 8           986
# 9           281

# %%
print(df.shape) # total number of records
# Out:
# (2071700, 6)

# %%
print(df.columns)# total columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'demo_age_5_17',
#        'demo_age_17_'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2071700 entries, 0 to 2071699
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   date           object
#  1   state          object
#  2   district       object
#  3   pincode        int64
#  4   demo_age_5_17  int64
#  5   demo_age_17_   int64
# dtypes: int64(3), object(3)
# memory usage: 94.8+ MB

# %%
df.describe()
# Out:
#             pincode  demo_age_5_17  demo_age_17_
# count  2.071700e+06   2.071700e+06  2.071700e+06
# mean   5.278318e+05   2.347552e+00  2.144701e+01
# std    1.972933e+05   1.490355e+01  1.252498e+02
# min    1.000000e+05   0.000000e+00  0.000000e+00
# 25%    3.964690e+05   0.000000e+00  2.000000e+00
# 50%    5.243220e+05   1.000000e+00  6.000000e+00
# 75%    6.955070e+05   2.000000e+00  1.500000e+01
# max    8.554560e+05   2.690000e+03  1.616600e+04

# %%
df_copy = df.copy() #create a copy dataframe

# %%
df_copy["date"]
# Out:
# 0          01-03-2025
# 1          01-03-2025
# 2          01-03-2025
# 3          01-03-2025
# 4          01-03-2025
#               ...
# 2071695    29-12-2025
# 2071696    29-12-2025
# 2071697    29-12-2025
# 2071698    29-12-2025
# 2071699    29-12-2025
# Name: date, Length: 2071700, dtype: object

# %%
df_copy['date'] = pd.to_datetime(df_copy['date'], format="%d-%m-%Y", errors='coerce')

# %%
df_copy["date"]
# Out:
# 0         2025-03-01
# 1         2025-03-01
# 2         2025-03-01
# 3         2025-03-01
# 4         2025-03-01
#              ...
# 2071695   2025-12-29
# 2071696   2025-12-29
# 2071697   2025-12-29
# 2071698   2025-12-29
# 2071699   2025-12-29
# Name: date, Length: 2071700, dtype: datetime64[ns]

# %%
#check null values
df_copy.isnull().sum()
# Out:
# date             0
# state            0
# district         0
# pincode          0
# demo_age_5_17    0
# demo_age_17_     0
# dtype: int64

# %%
#clean the text
df_copy['state'] = df_copy['state'].str.strip().str.title()
df_copy['district'] = df_copy['district'].str.strip().str.title()

# %%
df_copy.state.unique()
# Out:
# array(['Uttar Pradesh', 'Andhra Pradesh', 'Gujarat', 'Rajasthan',
#        'Karnataka', 'West Bengal', 'Telangana', 'Odisha', 'Maharashtra',
#        'Kerala', 'Bihar', 'Tamil Nadu', 'Madhya Pradesh', 'Assam',
#        'Tripura', 'Arunachal Pradesh', 'Punjab', 'Jharkhand', 'Delhi',
#        'Chandigarh', 'Chhattisgarh', 'Jammu And Kashmir', 'Mizoram',
#        'Nagaland', 'Himachal Pradesh', 'Goa', 'Haryana', 'Meghalaya',
#        'Uttarakhand', 'Manipur', 'Daman And Diu', 'Puducherry', 'Sikkim',
#        'Ladakh', 'Dadra And Nagar Haveli And Daman And Diu',
#        'Dadra And Nagar Haveli', 'Orissa', 'Pondicherry',
#        'Andaman & Nicobar Islands', 'Andaman And Nicobar Islands',
#        'Daman & Diu', 'West  Bengal', 'Jammu & Kashmir', 'Lakshadweep',
#        'Dadra & Nagar Haveli', 'Westbengal', 'West Bangal', 'Chhatisgarh',
#        'West Bengli', 'Darbhanga', 'Puttenahalli', 'Balanagar',
#        'Uttaranchal', '100000', 'Jaipur', 'Madanapalle', 'Nagpur',
#        'Raja Annamalai Puram'], dtype=object)

# %%
#remove the numaric column
df_copy = df_copy[~df_copy['state'].str.isnumeric()]

# %%
df_copy.state.unique()
# Out:
# array(['Uttar Pradesh', 'Andhra Pradesh', 'Gujarat', 'Rajasthan',
#        'Karnataka', 'West Bengal', 'Telangana', 'Odisha', 'Maharashtra',
#        'Kerala', 'Bihar', 'Tamil Nadu', 'Madhya Pradesh', 'Assam',
#        'Tripura', 'Arunachal Pradesh', 'Punjab', 'Jharkhand', 'Delhi',
#        'Chandigarh', 'Chhattisgarh', 'Jammu And Kashmir', 'Mizoram',
#        'Nagaland', 'Himachal Pradesh', 'Goa', 'Haryana', 'Meghalaya',
#        'Uttarakhand', 'Manipur', 'Daman And Diu', 'Puducherry', 'Sikkim',
#        'Ladakh', 'Dadra And Nagar Haveli And Daman And Diu',
#        'Dadra And Nagar Haveli', 'Orissa', 'Pondicherry',
#        'Andaman & Nicobar Islands', 'Andaman And Nicobar Islands',
#        'Daman & Diu', 'West  Bengal', 'Jammu & Kashmir', 'Lakshadweep',
#        'Dadra & Nagar Haveli', 'Westbengal', 'West Bangal', 'Chhatisgarh',
#        'West Bengli', 'Darbhanga', 'Puttenahalli', 'Balanagar',
#        'Uttaranchal', 'Jaipur', 'Madanapalle', 'Nagpur',
#        'Raja Annamalai Puram'], dtype=object)

# %%
# Normalise spacing and symbol
df_copy['state'] = (
    df_copy['state']
    .str.replace('&', 'And', regex=False)
    .str.replace(r'\s+', ' ', regex=True)
    .str.strip()
)

# %%
df_copy["state"].unique()
# Out:
# array(['Uttar Pradesh', 'Andhra Pradesh', 'Gujarat', 'Rajasthan',
#        'Karnataka', 'West Bengal', 'Telangana', 'Odisha', 'Maharashtra',
#        'Kerala', 'Bihar', 'Tamil Nadu', 'Madhya Pradesh', 'Assam',
#        'Tripura', 'Arunachal Pradesh', 'Punjab', 'Jharkhand', 'Delhi',
#        'Chandigarh', 'Chhattisgarh', 'Jammu And Kashmir', 'Mizoram',
#        'Nagaland', 'Himachal Pradesh', 'Goa', 'Haryana', 'Meghalaya',
#        'Uttarakhand', 'Manipur', 'Daman And Diu', 'Puducherry', 'Sikkim',
#        'Ladakh', 'Dadra And Nagar Haveli And Daman And Diu',
#        'Dadra And Nagar Haveli', 'Orissa', 'Pondicherry',
#        'Andaman And Nicobar Islands', 'Lakshadweep', 'Westbengal',
#        'West Bangal', 'Chhatisgarh', 'West Bengli', 'Darbhanga',
#        'Puttenahalli', 'Balanagar', 'Uttaranchal', 'Jaipur',
#        'Madanapalle', 'Nagpur', 'Raja Annamalai Puram'], dtype=object)

# %%
# Mapping state
state_mapping = {
    "West Bangal": "West Bengal",
    "Westbengal": "West Bengal",
    "West  Bengal": "West Bengal",
    "West Bengli":"West Bengal",
    "Orissa": "Odisha",
    "Pondicherry": "Puducherry",
    "Jammu And Kashmir": "Jammu And Kashmir",
    "Jammu And Kashmir": "Jammu And Kashmir",
    "Dadra And Nagar Haveli": "Dadra And Nagar Haveli And Daman And Diu",
    "Daman And Diu": "Dadra And Nagar Haveli And Daman And Diu",
    "Dadra And Nagar Haveli And Daman And Diu":
        "Dadra And Nagar Haveli And Daman And Diu",
    "Andaman And Nicobar Islands": "Andaman And Nicobar Islands",
    "Andaman And Nicobar Islands": "Andaman And Nicobar Islands"
}
df_copy["state"] = df_copy["state"].replace(state_mapping)

# %%
state_list = list(sorted(df_copy["state"].unique()))

# %%
type(state_list)
# Out:
# list

# %%
state_list
# Out:
# ['Andaman And Nicobar Islands',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Balanagar',
#  'Bihar',
#  'Chandigarh',
#  'Chhatisgarh',
#  'Chhattisgarh',
#  'Dadra And Nagar Haveli And Daman And Diu',
#  'Darbhanga',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jaipur',
#  'Jammu And Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Ladakh',
#  'Lakshadweep',
#  'Madanapalle',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Nagpur',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Puttenahalli',
#  'Raja Annamalai Puram',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'Uttaranchal',
#  'West Bengal']

# %%
df_copy["district"].unique()
# Out:
# array(['Gorakhpur', 'Chittoor', 'Rajkot', 'Srikakulam', 'Udaipur',
#        'Sikar', 'Tumakuru', 'Kurnool', 'Paschim Medinipur', 'Ghazipur',
#        'Patan', 'Mulugu', 'Ganganagar', 'Nayagarh', 'Nashik',
#        'Shivamogga', 'Thrissur', 'Hassan', 'Patna', 'Belgaum',
#        'Kancheepuram', 'Jabalpur', 'Chennai', 'Tinsukia', 'Jamui', 'Gaya',
#        'Bengaluru', 'Tiruppur', 'Jalgaon', 'Dhalai', 'Nabarangapur',
#        'Chittorgarh', 'Darbhanga', 'Purnia', 'Muzaffarnagar', 'Jaipur',
#        'Churu', 'Bharatpur', 'Jamnagar', 'Howrah', 'Ahmedabad',
#        'West Kameng', 'Jalor', 'Belagavi', 'Bahraich', 'Nagapattinam',
#        'Sheikhpura', 'Amritsar', 'Mysore', 'Alluri Sitharama Raju',
#        'Sitamarhi', 'Khunti', 'Saharanpur', 'Kanyakumari', 'Prakasam',
#        'Ananthapuramu', 'Hooghly', 'Central Delhi', 'Deoria', 'Giridih',
#        'Koraput', 'Shahjahanpur', 'Chhotaudepur', 'Jalandhar', 'Kannauj',
#        'Visakhapatnam', 'Jodhpur', 'Karimnagar', 'Amethi', 'Hyderabad',
#        'Salem', 'Cuddalore', 'Sabarkantha', 'Kolar', 'Nagpur',
#        'Porbandar', 'Chandigarh', 'Paschim Bardhaman', 'Devbhumi Dwarka',
#        'Nalgonda', 'Tawang', 'Muzaffarpur', 'Ganjam', 'Kawardha',
#        'East Godavari', 'Dhanbad', 'Gandhinagar', 'Puruliya',
#        'Siddharthnagar', 'Bara Banki', 'Saran', 'Hardoi',
#        'South 24 Parganas', 'Ambedkar Nagar', 'Tiruchirappalli', 'Indore',
#        'Tiruvannamalai', 'Kasaragod', 'Mumbai', 'Mysuru', 'Gopalganj',
#        'Surendra Nagar', 'Annamayya', 'Dindigul', 'Narayanpet', 'Tenkasi',
#        'Mahesana', 'North East Delhi', 'Firozpur', 'Araria', 'Auraiya',
#        'Krishnagiri', 'Betul', 'Satna', 'Sangareddy', 'Dahod',
#        'Prayagraj', 'Katihar', 'Anakapalli', 'Pratapgarh', 'Kallakurichi',
#        'Tikamgarh', 'Bhojpur', 'Jammu', 'Khargone', 'Aizawl', 'Dholpur',
#        'Kheda', 'Madhubani', 'Nawada', 'Solapur', 'Mayurbhanj', 'Rewa',
#        'Sambalpur', 'Tiruvallur', 'Bokaro', 'Dakshina Kannada',
#        'Purba Medinipur', 'North 24 Parganas', 'Peren', 'Kangra',
#        'Kendrapara', 'Palghar', 'Erode', 'Malappuram', 'Rajouri',
#        'North Goa', 'Balrampur', 'Surat', 'South Delhi', 'Khammam',
#        'Kendujhar', 'Ludhiana', 'Coimbatore', 'Rae Bareli', 'Amravati',
#        'Krishna', 'Bhadrak', 'Parbhani', 'Valsad', 'Azamgarh',
#        'Chhatarpur', 'Amroha', 'Jalna', 'Parvathipuram Manyam', 'Sirmaur',
#        'West Godavari', 'K.V. Rangareddy', 'Vijayapura', 'Unakoti',
#        'Virudhunagar', 'Vadodara', 'Sonipat', 'Sultanpur', 'Nadia',
#        'Warangal', 'Udupi', 'Baramula', 'Kalaburagi', 'Nandyal',
#        'Ernakulam', 'South West Delhi', 'Murshidabad',
#        'East Jaintia Hills', 'Mandya', 'Bijapur', 'Gonda', 'Kannur',
#        'Mainpuri', 'Medchal-Malkajgiri', 'Jajpur', 'Moradabad',
#        'Namakkal', 'Davangere', 'Ganderbal', 'Alappuzha', 'Arvalli',
#        'Rohtak', 'Samastipur', 'Medak', 'Ahmadnagar', 'Ratnagiri',
#        'Chamrajanagar', 'Buxar', 'Mumbai Suburban', 'Nagarkurnool',
#        'Charaideo', 'Peddapalli', 'West Champaran', 'Cuddapah',
#        'Khagaria', 'Pune', 'Chhindwara', 'East Champaran', 'Udalguri',
#        'Nalbari', 'Varanasi', 'Chitradurga', 'Adilabad', 'Karimganj',
#        'Nagaon', 'Kolkata', 'Gurgaon', 'East Singhbhum', 'Jajapur',
#        'Agar Malwa', 'Gwalior', 'Bijnor', 'Kaithal', 'Vellore', 'Ballari',
#        'Bankura', 'Gulbarga', 'Ramanathapuram', 'Chumukedima',
#        'Firozabad', 'Barddhaman', 'Farrukhabad', 'Hisar',
#        'Sri Muktsar Sahib', 'Basti', 'Baleswar', 'Chikkaballapur',
#        'Uttara Kannada', 'Botad', 'Jalpaiguri', 'Vizianagaram',
#        'Dhenkanal', 'Jaunpur', 'Umaria', 'Warangal Rural', 'Panchkula',
#        'Kakinada', 'Pithoragarh', 'Pathanamthitta', 'Palnadu',
#        'Maharajganj', 'Latehar', 'Srinagar', 'Badgam', 'Buldhana',
#        'Bikaner', 'Moga', 'Kaushambi', 'Alwar', 'Satara', 'Damoh', 'Puri',
#        'Chamba', 'Khorda', 'Morbi', 'Tirunelveli', 'Bundi', 'Kathua',
#        'Ananthapur', 'Chikkamagaluru', 'Maihar', 'Sitapur', 'Aligarh',
#        'Bagalkot', 'Lakhimpur', 'Kodagu', 'Rajsamand', 'Villupuram',
#        'Karbi Anglong', 'Gajapati', 'Shajapur', 'Anantnag', 'Karnal',
#        'Guna', 'Kheri', 'Kachchh', 'Purba Bardhaman', 'Angul',
#        'Chandrapur', 'Koppal', 'West Garo Hills', 'Vikarabad', 'Mau',
#        'Churachandpur', 'Dehradun', 'Saharsa', 'Sonbhadra', 'Jhalawar',
#        'Hoshangabad', 'Baloda Bazar', 'Pulwama', 'Tumkur', 'Nuapada',
#        'Aurangabad', 'Rupnagar', 'Sehore', 'Bulandshahr', 'Hanumakonda',
#        'Narsinghpur', 'Rohtas', 'Fatehpur', 'Jogulamba Gadwal', 'N. T. R',
#        'Osmanabad', 'Daman', 'Ajmer', 'Dharmapuri', 'Garhwa', 'Pali',
#        'Goalpara', 'Ayodhya', 'Anand', 'Hailakandi', 'Kozhikode', 'Mandi',
#        'Mandsaur', 'Raichur', 'Eluru', 'Kasganj', 'Kabeerdham',
#        'Tehri Garhwal', 'South Goa', 'Faizabad', 'Gadag',
#        'Dr. B. R. Ambedkar Konaseema', 'Baleshwar', 'Dausa', 'Siddipet',
#        'Nagaur', 'Ariyalur', 'Ballia', 'Kanpur Nagar', 'Neemuch',
#        'Guntur', 'Yavatmal', 'Niwari', 'Bharuch', 'Uttar Dinajpur',
#        'Munger', 'East Nimar', 'Latur', 'Ambala', 'Bathinda', 'Ramban',
#        'Lucknow', 'Nandurbar', 'Theni', 'Bhadradri Kothagudem',
#        'Nainital', 'Bhopal', 'Tirupattur', 'Mahabubnagar', 'Barpeta',
#        'Cuttack', 'Jashpur', 'Gir Somnath', 'Kolhapur', 'Datia',
#        'Jhunjhunun', 'Junagadh', 'Seoni', 'Agra', 'Thane', 'Rewari',
#        'Bilaspur', 'Raigarh', 'Thiruvarur', 'Jhajjar', 'Sant Kabir Nagar',
#        'Jagitial', 'Anantapur', 'Karur', 'Arwal', 'Shrawasti', 'Golaghat',
#        'Ujjain', 'Sirohi', 'Samba', 'Nizamabad', 'Bhilwara', 'Darjeeling',
#        'Marigaon', 'Rajgarh', 'Lohardaga', 'Akola', 'Pudukkottai',
#        'Siwan', 'Patiala', 'Katni', 'Sivaganga', 'Budgam', 'Kamrup Metro',
#        'Kapurthala', 'Beed', 'Banaskantha', 'Sonitpur', 'Tonk', 'Bhadohi',
#        'Dibrugarh', 'Sangrur', 'Thiruvananthapuram', 'Narmadapuram',
#        'Jorhat', 'Hanumangarh', 'Barwani', 'Birbhum', 'Dhule', 'Gadag *',
#        'Malda', 'Kanker', 'Yadadri.', 'Ghaziabad', 'Cachar', 'Lalitpur',
#        'Bastar', 'Boudh', 'Bhiwani', 'Mandla', 'Ri Bhoi', 'Simdega',
#        'Janjgir-Champa', 'Jagatsinghapur', 'Baksa', 'Dohad',
#        'Sas Nagar (Mohali)', 'Dharwad', 'Meerut', 'Mathura', 'Shivpuri',
#        'Gumla', 'Uttarkashi', 'Banswara', 'Bapatla', 'Kanniyakumari',
#        'Burhanpur', 'Allahabad', 'Bellary', 'Fazilka', 'Kaimur (Bhabua)',
#        'Kamareddy', 'Etah', 'Etawah', 'Vaishali', 'Gautam Buddha Nagar',
#        'Haridwar', 'Dhar', 'Balangir', 'Hathras', 'Sibsagar',
#        'Rangareddi', 'Nanded', 'Bongaigaon', 'Bandipore', 'Chamoli',
#        'Imphal East', 'Jind', 'Kota', 'Udham Singh Nagar',
#        'North West Delhi', 'Champawat', 'Shahdol', 'Una', 'Sirsa',
#        'Mewat', 'Suryapet', 'Faridabad', 'East Delhi', 'Gurdaspur',
#        'Mahasamund', 'Baran', 'Sri Sathya Sai', 'Surguja', 'Raipur',
#        'Balaghat', 'Yamuna Nagar', 'Madurai', 'Shahdara', 'Rampur',
#        'Kupwara', 'Dindori', 'Kulgam', 'Gadchiroli', 'North Delhi',
#        'Mumbai City', 'Haveri', 'West Delhi', 'Barmer', 'Balod',
#        'Ferozepur', 'Sagar', 'Hoshiarpur', 'Koriya', 'Bareilly', 'Punch',
#        'Raisen', 'Mahendragarh', 'Serchhip', 'Pauri Garhwal',
#        'Kurukshetra', 'Anuppur', 'Fatehabad', 'Durg', 'Korba', 'Vidisha',
#        'Dewas', 'Ratlam', 'Kolasib', 'Ramanagar', 'Doda',
#        'Sri Potti Sriramulu Nellore', 'Ashok Nagar', 'Mungeli',
#        'Rajnandgaon', 'Viluppuram', 'Sidhi', 'Bidar', 'Jhansi',
#        'Bhavnagar', 'Jhabua', 'Puducherry', 'Charkhi Dadri', 'Tirupati',
#        'Harda', 'Y. S. R', 'Bhind', 'Tarn Taran', 'Yadgir',
#        'Bangalore Rural', 'Vijayanagara', 'Raigad', 'Kokrajhar', 'Shimla',
#        'Pilibhit', 'West Sikkim', 'Alirajpur', 'Palamu', 'Karauli',
#        'Deoghar', 'Nellore', 'Sindhudurg', 'Chickmagalur', 'Hamirpur',
#        'Jharsuguda', 'Begusarai', 'Washim', 'Kargil', 'Dumka',
#        'Pathankot', 'Kalahandi', 'Shamli', 'Mahoba', 'Panna', 'Bageshwar',
#        'Dhamtari', 'Navsari', 'Palakkad', 'Sundergarh', 'Sambhal',
#        'Wayanad', 'Sahebganj', 'Sant Ravidas Nagar', 'Nalanda',
#        'Rayagada', 'Dhubri', 'West Khasi Hills', 'Almora', 'Sangli',
#        'Solan', 'Rudraprayag', 'Bangalore', 'Supaul', 'Khowai', 'Darrang',
#        'Jangoan', 'Kanpur Dehat', 'Gariyaband', 'Jehanabad', 'Singrauli',
#        'Kodarma', 'Thanjavur', 'Mahbubnagar', 'Hazaribagh', 'East',
#        'Debagarh', 'Panchmahals', 'West Tripura', 'Amreli',
#        'West Singhbhum', 'Madhepura', 'Baghpat', 'Sonapur', 'Dhemaji',
#        'Seraikela-Kharsawan', 'Zunheboto', 'Bhagalpur', 'Kushinagar',
#        'Kalimpong', 'Jhargram', 'Lakhisarai', 'Tapi', 'Gondiya',
#        'East Khasi Hills', 'Chhatrapati Sambhajinagar', 'Sawai Madhopur',
#        'Jaisalmer', 'Ranchi', 'Mancherial', 'Mirzapur', 'Cooch Behar',
#        'Senapati', 'Karaikal', 'Bemetara', 'Budaun', 'Hojai', 'Godda',
#        'Kottayam', 'Uttar Bastar Kanker', 'Thoothukkudi', 'Dimapur',
#        'Unnao', 'Kondagaon', 'Faridkot', 'Tamenglong', 'Bargarh',
#        'Khandwa', 'Hasan', 'Chatra', 'Jalaun', 'Dakshin Dinajpur',
#        'Mahisagar', 'Kollam', 'South Tripura', 'Shimoga', 'The Dangs',
#        'Nirmal', 'Hapur', 'Malkangiri', 'Thoubal', 'Lohit',
#        'Gaurela-Pendra-Marwahi', 'Komaram Bheem', 'West Nimar',
#        'North Tripura', 'Banka', 'Lunglei', 'Dungarpur', 'Wanaparthy',
#        'Bishnupur', 'Kandhamal', 'Mamit', 'South Salmara Mankachar',
#        'Morena', 'North Cachar Hills', 'Medchal?Malkajgiri', 'Kra Daadi',
#        'Surajpur', 'Mahabubabad', 'Mansa', 'Udhampur', 'Narsimhapur',
#        'Saiha', 'Sukma', 'Jiribam', 'Ranipet', 'Chandauli', 'Panipat',
#        'Koderma', 'The Nilgiris', 'Idukki', 'Kamrup',
#        'Jayashankar Bhupalpally', 'Warangal Urban', 'Sheohar',
#        'Upper Siang', 'Mauganj', 'Diu', 'Malerkotla', 'Kiphire',
#        'Mohla-Manpur-Ambagarh Chouki', 'Palwal',
#        'Khairagarh Chhuikhadan Gandai', 'Kishtwar', 'Wardha',
#        'Kishanganj', 'Sheopur', 'Narmada', 'Chamarajanagar',
#        'Chikmagalur', 'Davanagere', 'Leh', 'Harda *', 'Pandhurna',
#        'Ahmed Nagar', 'Bhandara', 'Bid', 'Buldana', 'Dharashiv', 'Gondia',
#        'Gondiya *', 'Hingoli', 'Purba Champaran', 'Purnea', 'Sheikpura',
#        'Dakshin Bastar Dantewada', 'Dantewada',
#        'Manendragarh–Chirmiri–Bharatpur', 'Sakti',
#        'Dadra And Nagar Haveli', 'Najafgarh', 'New Delhi', 'North East',
#        'South East Delhi', 'Ahmadabad', 'Banas Kantha', 'Panch Mahals',
#        'Sabar Kantha', 'Surendranagar', 'Yamunanagar', 'Kinnaur', 'Kullu',
#        'Garhwa *', 'Hazaribag', 'Jamtara', 'Pakaur', 'Pakur', 'Palamau',
#        'Purbi Singhbhum', 'Ramgarh', 'Mumbai( Sub Urban )', 'Chandel',
#        'Imphal West', 'North Garo Hills', 'South Garo Hills',
#        'South West Garo Hills', 'West Jaintia Hills', 'Champhai',
#        'Mammit', 'Kohima', 'Longleng', 'Meluri', 'Mokokchung', 'Mon',
#        'Tseminyu', 'Anugul', 'Baudh', 'Jagatsinghpur', 'Khordha',
#        'Sundargarh', 'Pondicherry', 'Barnala', 'Fatehgarh Sahib',
#        'Muktsar', 'Nawanshahr', 'S.A.S Nagar(Mohali)',
#        'Shaheed Bhagat Singh Nagar', 'Chittaurgarh', 'Deeg', 'Andamans',
#        'South Andaman', 'K.V.Rangareddy', 'Karim Nagar', 'Mahabub Nagar',
#        'Anjaw', 'Changlang', 'East Siang', 'Kamle', 'Longding',
#        'West Siang', 'Biswanath', 'Majuli', 'Sribhumi',
#        'Tamulpur District', 'West Karbi Anglong', 'Banda', 'Bulandshahar',
#        'Chitrakoot', 'Kushinagar *', 'Sant Ravidas Nagar Bhadohi',
#        'Hardwar', 'Alipurduar', 'Bardhaman', 'Darjiling',
#        'East Midnapore', 'Haora', 'Hugli', 'Koch Bihar', 'Maldah',
#        'North Dinajpur', 'North Twenty Four Parganas', 'Purulia',
#        'South Dinajpur', 'South Twenty Four Parganas', 'West Midnapore',
#        'North And Middle Andaman', 'North Sikkim', 'South',
#        'South Sikkim', 'West', 'Chengalpattu', 'Mayiladuthurai',
#        'Perambalur', 'Thiruvallur', 'Medchal−Malkajgiri',
#        'Rajanna Sircilla', 'Rangareddy', 'Gomati', 'Sepahijala',
#        'Barabanki', 'Namsai', 'Tirap', 'Upper Subansiri', 'Bajali',
#        'Chirang', 'Pashchim Champaran', 'Samstipur',
#        'Sarangarh-Bilaigarh', 'East Kameng', 'Kurung Kumey',
#        'Lower Siang', 'Lower Subansiri', 'Papum Pare', 'Aurangabad(Bh)',
#        'Janjgir Champa', 'Jyotiba Phule Nagar', 'Mahrajganj',
#        'Lahul And Spiti', 'Reasi', 'Shupiyan', 'Bengaluru South',
#        'Chamrajnagar', 'East Sikkim', 'Namchi', 'North', 'Dhalai  *',
#        'Kasargod', 'Lakshadweep', 'Chatrapati Sambhaji Nagar',
#        'East Garo Hills', 'Eastern West Khasi Hills', 'Lawngtlai', 'Phek',
#        'Wokha', 'Subarnapur', 'Dhaulpur', 'Jhunjhunu', 'Siang', 'Monghyr',
#        'Dadra & Nagar Haveli', 'Jangaon', 'Warangal (Urban)',
#        'Nandurbar *', 'Raigarh(Mh)', 'Washim *', 'Ukhrul',
#        'South West Khasi Hills', 'Saitual', 'Niuland', 'Tuensang',
#        'Nicobar', 'Pashchimi Singhbhum', 'Sahibganj', 'Haveri *',
#        'Bagalkot *', 'Yanam', 'Dibang Valley', 'Lower Dibang Valley',
#        'Bagpat', 'Garhwal', 'Kakching', 'Chamarajanagar *', 'Medinipur',
#        'Mangan', 'Dima Hasao', 'Janjgir - Champa', 'Narayanpur',
#        'Lahul & Spiti', 'Leparada', 'Shi-Yomi', 'Lahaul And Spiti',
#        'Khawzawl', 'Noklak', 'South 24 Pargana', 'West Medinipur',
#        'Shamator', 'Tirupathur', 'East Midnapur',
#        'Mohalla-Manpur-Ambagarh Chowki', 'Kanchipuram', 'Jaintia Hills',
#        'Bhabua', 'Bardez', 'Bengaluru Rural', 'Hawrah', 'Hooghiy',
#        'Pherzawl', 'Jajapur  *', 'Rajauri', 'Jalore', 'Salumbar',
#        'Nicobars', 'Beawar', 'Didwana-Kuchaman', 'Kotputli-Behror',
#        'Phalodi', 'Pakke Kessang', 'Hnahthial', 'Balotra', 'Leh (Ladakh)',
#        'Khairthal-Tijara', 'Ahilyanagar', 'Tiswadi',
#        'Near University Thana', 'South Dumdum(M)', 'Raebareli',
#        'Dist : Thane', '5Th Cross', 'Balianta', 'Bally Jagachha',
#        'Baghpat *', 'Mohali', 'South  Twenty Four Parganas', 'Domjur',
#        'Bicholim', 'Naihati Anandabazar', 'Anugal', 'Idpl Colony',
#        'Udham Singh Nagar *', 'Poonch', 'Kangpokpi',
#        'Near Meera Hospital', 'Tuticorin', 'Kadiri Road', 'Hingoli *',
#        'Tiruvarur', 'Udupi *', 'Jyotiba Phule Nagar *', 'Bhadrak(R)',
#        'Chitrakoot *', 'Chandauli *', 'Bijapur(Kar)', 'Bandipur',
#        'Near Uday Nagar Nit Garden', 'Medchalâ\x88\x92Malkajgiri',
#        'Near Dhyana Ashram'], dtype=object)

# %%
#remove the unwanted symbol
import re

df_copy['district'] = (
    df_copy['district']
    .astype(str)
    .str.replace('&', 'And', regex=False)
    .str.replace(r'\*+', '', regex=True)               # remove *
    .str.replace(r'\(.*?\)', '', regex=True)           # remove anything in ()
    .str.replace(r'–|−|—', '-', regex=True)            # normalize hyphens
    .str.replace(r'\s+', ' ', regex=True)              # extra spaces
    .str.strip()
    .str.title()
)

# %%
df_copy["district"].unique()
# Out:
# array(['Gorakhpur', 'Chittoor', 'Rajkot', 'Srikakulam', 'Udaipur',
#        'Sikar', 'Tumakuru', 'Kurnool', 'Paschim Medinipur', 'Ghazipur',
#        'Patan', 'Mulugu', 'Ganganagar', 'Nayagarh', 'Nashik',
#        'Shivamogga', 'Thrissur', 'Hassan', 'Patna', 'Belgaum',
#        'Kancheepuram', 'Jabalpur', 'Chennai', 'Tinsukia', 'Jamui', 'Gaya',
#        'Bengaluru', 'Tiruppur', 'Jalgaon', 'Dhalai', 'Nabarangapur',
#        'Chittorgarh', 'Darbhanga', 'Purnia', 'Muzaffarnagar', 'Jaipur',
#        'Churu', 'Bharatpur', 'Jamnagar', 'Howrah', 'Ahmedabad',
#        'West Kameng', 'Jalor', 'Belagavi', 'Bahraich', 'Nagapattinam',
#        'Sheikhpura', 'Amritsar', 'Mysore', 'Alluri Sitharama Raju',
#        'Sitamarhi', 'Khunti', 'Saharanpur', 'Kanyakumari', 'Prakasam',
#        'Ananthapuramu', 'Hooghly', 'Central Delhi', 'Deoria', 'Giridih',
#        'Koraput', 'Shahjahanpur', 'Chhotaudepur', 'Jalandhar', 'Kannauj',
#        'Visakhapatnam', 'Jodhpur', 'Karimnagar', 'Amethi', 'Hyderabad',
#        'Salem', 'Cuddalore', 'Sabarkantha', 'Kolar', 'Nagpur',
#        'Porbandar', 'Chandigarh', 'Paschim Bardhaman', 'Devbhumi Dwarka',
#        'Nalgonda', 'Tawang', 'Muzaffarpur', 'Ganjam', 'Kawardha',
#        'East Godavari', 'Dhanbad', 'Gandhinagar', 'Puruliya',
#        'Siddharthnagar', 'Bara Banki', 'Saran', 'Hardoi',
#        'South 24 Parganas', 'Ambedkar Nagar', 'Tiruchirappalli', 'Indore',
#        'Tiruvannamalai', 'Kasaragod', 'Mumbai', 'Mysuru', 'Gopalganj',
#        'Surendra Nagar', 'Annamayya', 'Dindigul', 'Narayanpet', 'Tenkasi',
#        'Mahesana', 'North East Delhi', 'Firozpur', 'Araria', 'Auraiya',
#        'Krishnagiri', 'Betul', 'Satna', 'Sangareddy', 'Dahod',
#        'Prayagraj', 'Katihar', 'Anakapalli', 'Pratapgarh', 'Kallakurichi',
#        'Tikamgarh', 'Bhojpur', 'Jammu', 'Khargone', 'Aizawl', 'Dholpur',
#        'Kheda', 'Madhubani', 'Nawada', 'Solapur', 'Mayurbhanj', 'Rewa',
#        'Sambalpur', 'Tiruvallur', 'Bokaro', 'Dakshina Kannada',
#        'Purba Medinipur', 'North 24 Parganas', 'Peren', 'Kangra',
#        'Kendrapara', 'Palghar', 'Erode', 'Malappuram', 'Rajouri',
#        'North Goa', 'Balrampur', 'Surat', 'South Delhi', 'Khammam',
#        'Kendujhar', 'Ludhiana', 'Coimbatore', 'Rae Bareli', 'Amravati',
#        'Krishna', 'Bhadrak', 'Parbhani', 'Valsad', 'Azamgarh',
#        'Chhatarpur', 'Amroha', 'Jalna', 'Parvathipuram Manyam', 'Sirmaur',
#        'West Godavari', 'K.V. Rangareddy', 'Vijayapura', 'Unakoti',
#        'Virudhunagar', 'Vadodara', 'Sonipat', 'Sultanpur', 'Nadia',
#        'Warangal', 'Udupi', 'Baramula', 'Kalaburagi', 'Nandyal',
#        'Ernakulam', 'South West Delhi', 'Murshidabad',
#        'East Jaintia Hills', 'Mandya', 'Bijapur', 'Gonda', 'Kannur',
#        'Mainpuri', 'Medchal-Malkajgiri', 'Jajpur', 'Moradabad',
#        'Namakkal', 'Davangere', 'Ganderbal', 'Alappuzha', 'Arvalli',
#        'Rohtak', 'Samastipur', 'Medak', 'Ahmadnagar', 'Ratnagiri',
#        'Chamrajanagar', 'Buxar', 'Mumbai Suburban', 'Nagarkurnool',
#        'Charaideo', 'Peddapalli', 'West Champaran', 'Cuddapah',
#        'Khagaria', 'Pune', 'Chhindwara', 'East Champaran', 'Udalguri',
#        'Nalbari', 'Varanasi', 'Chitradurga', 'Adilabad', 'Karimganj',
#        'Nagaon', 'Kolkata', 'Gurgaon', 'East Singhbhum', 'Jajapur',
#        'Agar Malwa', 'Gwalior', 'Bijnor', 'Kaithal', 'Vellore', 'Ballari',
#        'Bankura', 'Gulbarga', 'Ramanathapuram', 'Chumukedima',
#        'Firozabad', 'Barddhaman', 'Farrukhabad', 'Hisar',
#        'Sri Muktsar Sahib', 'Basti', 'Baleswar', 'Chikkaballapur',
#        'Uttara Kannada', 'Botad', 'Jalpaiguri', 'Vizianagaram',
#        'Dhenkanal', 'Jaunpur', 'Umaria', 'Warangal Rural', 'Panchkula',
#        'Kakinada', 'Pithoragarh', 'Pathanamthitta', 'Palnadu',
#        'Maharajganj', 'Latehar', 'Srinagar', 'Badgam', 'Buldhana',
#        'Bikaner', 'Moga', 'Kaushambi', 'Alwar', 'Satara', 'Damoh', 'Puri',
#        'Chamba', 'Khorda', 'Morbi', 'Tirunelveli', 'Bundi', 'Kathua',
#        'Ananthapur', 'Chikkamagaluru', 'Maihar', 'Sitapur', 'Aligarh',
#        'Bagalkot', 'Lakhimpur', 'Kodagu', 'Rajsamand', 'Villupuram',
#        'Karbi Anglong', 'Gajapati', 'Shajapur', 'Anantnag', 'Karnal',
#        'Guna', 'Kheri', 'Kachchh', 'Purba Bardhaman', 'Angul',
#        'Chandrapur', 'Koppal', 'West Garo Hills', 'Vikarabad', 'Mau',
#        'Churachandpur', 'Dehradun', 'Saharsa', 'Sonbhadra', 'Jhalawar',
#        'Hoshangabad', 'Baloda Bazar', 'Pulwama', 'Tumkur', 'Nuapada',
#        'Aurangabad', 'Rupnagar', 'Sehore', 'Bulandshahr', 'Hanumakonda',
#        'Narsinghpur', 'Rohtas', 'Fatehpur', 'Jogulamba Gadwal', 'N. T. R',
#        'Osmanabad', 'Daman', 'Ajmer', 'Dharmapuri', 'Garhwa', 'Pali',
#        'Goalpara', 'Ayodhya', 'Anand', 'Hailakandi', 'Kozhikode', 'Mandi',
#        'Mandsaur', 'Raichur', 'Eluru', 'Kasganj', 'Kabeerdham',
#        'Tehri Garhwal', 'South Goa', 'Faizabad', 'Gadag',
#        'Dr. B. R. Ambedkar Konaseema', 'Baleshwar', 'Dausa', 'Siddipet',
#        'Nagaur', 'Ariyalur', 'Ballia', 'Kanpur Nagar', 'Neemuch',
#        'Guntur', 'Yavatmal', 'Niwari', 'Bharuch', 'Uttar Dinajpur',
#        'Munger', 'East Nimar', 'Latur', 'Ambala', 'Bathinda', 'Ramban',
#        'Lucknow', 'Nandurbar', 'Theni', 'Bhadradri Kothagudem',
#        'Nainital', 'Bhopal', 'Tirupattur', 'Mahabubnagar', 'Barpeta',
#        'Cuttack', 'Jashpur', 'Gir Somnath', 'Kolhapur', 'Datia',
#        'Jhunjhunun', 'Junagadh', 'Seoni', 'Agra', 'Thane', 'Rewari',
#        'Bilaspur', 'Raigarh', 'Thiruvarur', 'Jhajjar', 'Sant Kabir Nagar',
#        'Jagitial', 'Anantapur', 'Karur', 'Arwal', 'Shrawasti', 'Golaghat',
#        'Ujjain', 'Sirohi', 'Samba', 'Nizamabad', 'Bhilwara', 'Darjeeling',
#        'Marigaon', 'Rajgarh', 'Lohardaga', 'Akola', 'Pudukkottai',
#        'Siwan', 'Patiala', 'Katni', 'Sivaganga', 'Budgam', 'Kamrup Metro',
#        'Kapurthala', 'Beed', 'Banaskantha', 'Sonitpur', 'Tonk', 'Bhadohi',
#        'Dibrugarh', 'Sangrur', 'Thiruvananthapuram', 'Narmadapuram',
#        'Jorhat', 'Hanumangarh', 'Barwani', 'Birbhum', 'Dhule', 'Malda',
#        'Kanker', 'Yadadri.', 'Ghaziabad', 'Cachar', 'Lalitpur', 'Bastar',
#        'Boudh', 'Bhiwani', 'Mandla', 'Ri Bhoi', 'Simdega',
#        'Janjgir-Champa', 'Jagatsinghapur', 'Baksa', 'Dohad', 'Sas Nagar',
#        'Dharwad', 'Meerut', 'Mathura', 'Shivpuri', 'Gumla', 'Uttarkashi',
#        'Banswara', 'Bapatla', 'Kanniyakumari', 'Burhanpur', 'Allahabad',
#        'Bellary', 'Fazilka', 'Kaimur', 'Kamareddy', 'Etah', 'Etawah',
#        'Vaishali', 'Gautam Buddha Nagar', 'Haridwar', 'Dhar', 'Balangir',
#        'Hathras', 'Sibsagar', 'Rangareddi', 'Nanded', 'Bongaigaon',
#        'Bandipore', 'Chamoli', 'Imphal East', 'Jind', 'Kota',
#        'Udham Singh Nagar', 'North West Delhi', 'Champawat', 'Shahdol',
#        'Una', 'Sirsa', 'Mewat', 'Suryapet', 'Faridabad', 'East Delhi',
#        'Gurdaspur', 'Mahasamund', 'Baran', 'Sri Sathya Sai', 'Surguja',
#        'Raipur', 'Balaghat', 'Yamuna Nagar', 'Madurai', 'Shahdara',
#        'Rampur', 'Kupwara', 'Dindori', 'Kulgam', 'Gadchiroli',
#        'North Delhi', 'Mumbai City', 'Haveri', 'West Delhi', 'Barmer',
#        'Balod', 'Ferozepur', 'Sagar', 'Hoshiarpur', 'Koriya', 'Bareilly',
#        'Punch', 'Raisen', 'Mahendragarh', 'Serchhip', 'Pauri Garhwal',
#        'Kurukshetra', 'Anuppur', 'Fatehabad', 'Durg', 'Korba', 'Vidisha',
#        'Dewas', 'Ratlam', 'Kolasib', 'Ramanagar', 'Doda',
#        'Sri Potti Sriramulu Nellore', 'Ashok Nagar', 'Mungeli',
#        'Rajnandgaon', 'Viluppuram', 'Sidhi', 'Bidar', 'Jhansi',
#        'Bhavnagar', 'Jhabua', 'Puducherry', 'Charkhi Dadri', 'Tirupati',
#        'Harda', 'Y. S. R', 'Bhind', 'Tarn Taran', 'Yadgir',
#        'Bangalore Rural', 'Vijayanagara', 'Raigad', 'Kokrajhar', 'Shimla',
#        'Pilibhit', 'West Sikkim', 'Alirajpur', 'Palamu', 'Karauli',
#        'Deoghar', 'Nellore', 'Sindhudurg', 'Chickmagalur', 'Hamirpur',
#        'Jharsuguda', 'Begusarai', 'Washim', 'Kargil', 'Dumka',
#        'Pathankot', 'Kalahandi', 'Shamli', 'Mahoba', 'Panna', 'Bageshwar',
#        'Dhamtari', 'Navsari', 'Palakkad', 'Sundergarh', 'Sambhal',
#        'Wayanad', 'Sahebganj', 'Sant Ravidas Nagar', 'Nalanda',
#        'Rayagada', 'Dhubri', 'West Khasi Hills', 'Almora', 'Sangli',
#        'Solan', 'Rudraprayag', 'Bangalore', 'Supaul', 'Khowai', 'Darrang',
#        'Jangoan', 'Kanpur Dehat', 'Gariyaband', 'Jehanabad', 'Singrauli',
#        'Kodarma', 'Thanjavur', 'Mahbubnagar', 'Hazaribagh', 'East',
#        'Debagarh', 'Panchmahals', 'West Tripura', 'Amreli',
#        'West Singhbhum', 'Madhepura', 'Baghpat', 'Sonapur', 'Dhemaji',
#        'Seraikela-Kharsawan', 'Zunheboto', 'Bhagalpur', 'Kushinagar',
#        'Kalimpong', 'Jhargram', 'Lakhisarai', 'Tapi', 'Gondiya',
#        'East Khasi Hills', 'Chhatrapati Sambhajinagar', 'Sawai Madhopur',
#        'Jaisalmer', 'Ranchi', 'Mancherial', 'Mirzapur', 'Cooch Behar',
#        'Senapati', 'Karaikal', 'Bemetara', 'Budaun', 'Hojai', 'Godda',
#        'Kottayam', 'Uttar Bastar Kanker', 'Thoothukkudi', 'Dimapur',
#        'Unnao', 'Kondagaon', 'Faridkot', 'Tamenglong', 'Bargarh',
#        'Khandwa', 'Hasan', 'Chatra', 'Jalaun', 'Dakshin Dinajpur',
#        'Mahisagar', 'Kollam', 'South Tripura', 'Shimoga', 'The Dangs',
#        'Nirmal', 'Hapur', 'Malkangiri', 'Thoubal', 'Lohit',
#        'Gaurela-Pendra-Marwahi', 'Komaram Bheem', 'West Nimar',
#        'North Tripura', 'Banka', 'Lunglei', 'Dungarpur', 'Wanaparthy',
#        'Bishnupur', 'Kandhamal', 'Mamit', 'South Salmara Mankachar',
#        'Morena', 'North Cachar Hills', 'Medchal?Malkajgiri', 'Kra Daadi',
#        'Surajpur', 'Mahabubabad', 'Mansa', 'Udhampur', 'Narsimhapur',
#        'Saiha', 'Sukma', 'Jiribam', 'Ranipet', 'Chandauli', 'Panipat',
#        'Koderma', 'The Nilgiris', 'Idukki', 'Kamrup',
#        'Jayashankar Bhupalpally', 'Warangal Urban', 'Sheohar',
#        'Upper Siang', 'Mauganj', 'Diu', 'Malerkotla', 'Kiphire',
#        'Mohla-Manpur-Ambagarh Chouki', 'Palwal',
#        'Khairagarh Chhuikhadan Gandai', 'Kishtwar', 'Wardha',
#        'Kishanganj', 'Sheopur', 'Narmada', 'Chamarajanagar',
#        'Chikmagalur', 'Davanagere', 'Leh', 'Pandhurna', 'Ahmed Nagar',
#        'Bhandara', 'Bid', 'Buldana', 'Dharashiv', 'Gondia', 'Hingoli',
#        'Purba Champaran', 'Purnea', 'Sheikpura',
#        'Dakshin Bastar Dantewada', 'Dantewada',
#        'Manendragarh-Chirmiri-Bharatpur', 'Sakti',
#        'Dadra And Nagar Haveli', 'Najafgarh', 'New Delhi', 'North East',
#        'South East Delhi', 'Ahmadabad', 'Banas Kantha', 'Panch Mahals',
#        'Sabar Kantha', 'Surendranagar', 'Yamunanagar', 'Kinnaur', 'Kullu',
#        'Hazaribag', 'Jamtara', 'Pakaur', 'Pakur', 'Palamau',
#        'Purbi Singhbhum', 'Ramgarh', 'Chandel', 'Imphal West',
#        'North Garo Hills', 'South Garo Hills', 'South West Garo Hills',
#        'West Jaintia Hills', 'Champhai', 'Mammit', 'Kohima', 'Longleng',
#        'Meluri', 'Mokokchung', 'Mon', 'Tseminyu', 'Anugul', 'Baudh',
#        'Jagatsinghpur', 'Khordha', 'Sundargarh', 'Pondicherry', 'Barnala',
#        'Fatehgarh Sahib', 'Muktsar', 'Nawanshahr', 'S.A.S Nagar',
#        'Shaheed Bhagat Singh Nagar', 'Chittaurgarh', 'Deeg', 'Andamans',
#        'South Andaman', 'K.V.Rangareddy', 'Karim Nagar', 'Mahabub Nagar',
#        'Anjaw', 'Changlang', 'East Siang', 'Kamle', 'Longding',
#        'West Siang', 'Biswanath', 'Majuli', 'Sribhumi',
#        'Tamulpur District', 'West Karbi Anglong', 'Banda', 'Bulandshahar',
#        'Chitrakoot', 'Sant Ravidas Nagar Bhadohi', 'Hardwar',
#        'Alipurduar', 'Bardhaman', 'Darjiling', 'East Midnapore', 'Haora',
#        'Hugli', 'Koch Bihar', 'Maldah', 'North Dinajpur',
#        'North Twenty Four Parganas', 'Purulia', 'South Dinajpur',
#        'South Twenty Four Parganas', 'West Midnapore',
#        'North And Middle Andaman', 'North Sikkim', 'South',
#        'South Sikkim', 'West', 'Chengalpattu', 'Mayiladuthurai',
#        'Perambalur', 'Thiruvallur', 'Rajanna Sircilla', 'Rangareddy',
#        'Gomati', 'Sepahijala', 'Barabanki', 'Namsai', 'Tirap',
#        'Upper Subansiri', 'Bajali', 'Chirang', 'Pashchim Champaran',
#        'Samstipur', 'Sarangarh-Bilaigarh', 'East Kameng', 'Kurung Kumey',
#        'Lower Siang', 'Lower Subansiri', 'Papum Pare', 'Janjgir Champa',
#        'Jyotiba Phule Nagar', 'Mahrajganj', 'Lahul And Spiti', 'Reasi',
#        'Shupiyan', 'Bengaluru South', 'Chamrajnagar', 'East Sikkim',
#        'Namchi', 'North', 'Kasargod', 'Lakshadweep',
#        'Chatrapati Sambhaji Nagar', 'East Garo Hills',
#        'Eastern West Khasi Hills', 'Lawngtlai', 'Phek', 'Wokha',
#        'Subarnapur', 'Dhaulpur', 'Jhunjhunu', 'Siang', 'Monghyr',
#        'Jangaon', 'Ukhrul', 'South West Khasi Hills', 'Saitual',
#        'Niuland', 'Tuensang', 'Nicobar', 'Pashchimi Singhbhum',
#        'Sahibganj', 'Yanam', 'Dibang Valley', 'Lower Dibang Valley',
#        'Bagpat', 'Garhwal', 'Kakching', 'Medinipur', 'Mangan',
#        'Dima Hasao', 'Janjgir - Champa', 'Narayanpur', 'Leparada',
#        'Shi-Yomi', 'Lahaul And Spiti', 'Khawzawl', 'Noklak',
#        'South 24 Pargana', 'West Medinipur', 'Shamator', 'Tirupathur',
#        'East Midnapur', 'Mohalla-Manpur-Ambagarh Chowki', 'Kanchipuram',
#        'Jaintia Hills', 'Bhabua', 'Bardez', 'Bengaluru Rural', 'Hawrah',
#        'Hooghiy', 'Pherzawl', 'Rajauri', 'Jalore', 'Salumbar', 'Nicobars',
#        'Beawar', 'Didwana-Kuchaman', 'Kotputli-Behror', 'Phalodi',
#        'Pakke Kessang', 'Hnahthial', 'Balotra', 'Khairthal-Tijara',
#        'Ahilyanagar', 'Tiswadi', 'Near University Thana', 'South Dumdum',
#        'Raebareli', 'Dist : Thane', '5Th Cross', 'Balianta',
#        'Bally Jagachha', 'Mohali', 'Domjur', 'Bicholim',
#        'Naihati Anandabazar', 'Anugal', 'Idpl Colony', 'Poonch',
#        'Kangpokpi', 'Near Meera Hospital', 'Tuticorin', 'Kadiri Road',
#        'Tiruvarur', 'Bandipur', 'Near Uday Nagar Nit Garden',
#        'Medchalâ\x88\x92Malkajgiri', 'Near Dhyana Ashram'], dtype=object)

# %%
district_mapping = {
    # Karnataka
    "Bangalore": "Bengaluru",
    "Bangalore Urban": "Bengaluru Urban",
    "Bangalore Rural": "Bengaluru Rural",
    "Mysore": "Mysuru",
    "Tumkur": "Tumakuru",
    "Bellary": "Ballari",
    "Belgaum": "Belagavi",
    "Gulbarga": "Kalaburagi",
    "Shimoga": "Shivamogga",

    # Telangana
    "Mahbubnagar": "Mahabubnagar",
    "Rangareddi": "Ranga Reddy",
    "K.V. Rangareddy": "Ranga Reddy",
    "K.V.Rangareddy": "Ranga Reddy",

    # Gujarat
    "Ahmadabad": "Ahmedabad",
    "Ahmed Nagar": "Ahmednagar",
    "Surendra Nagar": "Surendranagar",
    "Sabar Kantha": "Sabarkantha",

    # West Bengal
    "Coochbehar": "Cooch Behar",
    "Koch Bihar": "Cooch Behar",
    "Haora": "Howrah",
    "Hawrah": "Howrah",
    "Darjiling": "Darjeeling",
    "Burdwan": "Bardhaman",

    # Uttar Pradesh
    "Allahabad": "Prayagraj",
    "Faizabad": "Ayodhya",
    "Raebareli": "Rae Bareli",
    "Bulandshahar": "Bulandshahr",
    "Barabanki": "Bara Banki",

    # Tamil Nadu
    "Tuticorin": "Thoothukkudi",
    "Kancheepuram": "Kanchipuram",
    "Viluppuram": "Villupuram",
}

# %%
df_copy["district"] = df_copy["district"].replace(district_mapping)

# %%
bihar_district_mapping = {
    # Champaran
    "Purbi Champaran": "East Champaran",
    "Purba Champaran": "East Champaran",
    "East Champaran": "East Champaran",
    "Pashchim Champaran": "West Champaran",
    "West Champaran": "West Champaran",

    # Common spellings / variants
    "Bara Banki": "Barabanki",   # (NOTE: actually UP, remove if appears under Bihar)
    "Monghyr": "Munger",
    "Samstipur": "Samastipur",
    "Sheikpura": "Sheikhpura",
    "Bhabua": "Kaimur",
    "Kaimur": "Kaimur",
    "Kaimur (Bhabua)": "Kaimur",

    # Core Bihar districts (already correct)
    "Araria": "Araria",
    "Arwal": "Arwal",
    "Aurangabad": "Aurangabad",
    "Banka": "Banka",
    "Begusarai": "Begusarai",
    "Bhagalpur": "Bhagalpur",
    "Bhojpur": "Bhojpur",
    "Buxar": "Buxar",
    "Darbhanga": "Darbhanga",
    "Gaya": "Gaya",
    "Gopalganj": "Gopalganj",
    "Jamui": "Jamui",
    "Jehanabad": "Jehanabad",
    "Katihar": "Katihar",
    "Khagaria": "Khagaria",
    "Kishanganj": "Kishanganj",
    "Lakhisarai": "Lakhisarai",
    "Madhepura": "Madhepura",
    "Madhubani": "Madhubani",
    "Muzaffarpur": "Muzaffarpur",
    "Nalanda": "Nalanda",
    "Nawada": "Nawada",
    "Patna": "Patna",
    "Purnia": "Purnia",
    "Purnea": "Purnia",
    "Rohtas": "Rohtas",
    "Saharsa": "Saharsa",
    "Samastipur": "Samastipur",
    "Saran": "Saran",
    "Sheohar": "Sheohar",
    "Sitamarhi": "Sitamarhi",
    "Siwan": "Siwan",
    "Supaul": "Supaul",
    "Vaishali": "Vaishali",
}
df_copy["district"] = df_copy["district"].replace(bihar_district_mapping)

# %%
west_bengal_district_mapping = {
    "Coochbehar": "Cooch Behar",
    "Koch Bihar": "Cooch Behar",
    "Haora": "Howrah",
    "Hawrah": "Howrah",
    "Darjiling": "Darjeeling",
    "Burdwan": "Bardhaman",
    "Barddhaman": "Bardhaman",
    "North Twenty Four Parganas": "North 24 Parganas",
    "South Twenty Four Parganas": "South 24 Parganas",
    "Medinipur West": "Paschim Medinipur",
    "West Midnapore": "Paschim Medinipur",
    "East Midnapore": "Purba Medinipur",
    "Puruliya": "Purulia",

    # already standard
    "Alipurduar": "Alipurduar",
    "Bankura": "Bankura",
    "Birbhum": "Birbhum",
    "Dakshin Dinajpur": "Dakshin Dinajpur",
    "Hooghly": "Hooghly",
    "Howrah": "Howrah",
    "Jalpaiguri": "Jalpaiguri",
    "Jhargram": "Jhargram",
    "Kalimpong": "Kalimpong",
    "Kolkata": "Kolkata",
    "Malda": "Malda",
    "Murshidabad": "Murshidabad",
    "Nadia": "Nadia",
    "North 24 Parganas": "North 24 Parganas",
    "Paschim Bardhaman": "Paschim Bardhaman",
    "Purba Bardhaman": "Purba Bardhaman",
    "Purba Medinipur": "Purba Medinipur",
    "Purulia": "Purulia",
    "South 24 Parganas": "South 24 Parganas",
    "Uttar Dinajpur": "Uttar Dinajpur",
}
df_copy["district"] = df_copy["district"].replace(west_bengal_district_mapping)

# %%
karnataka_district_mapping = {
    "Bangalore": "Bengaluru",
    "Bangalore Urban": "Bengaluru Urban",
    "Bangalore Rural": "Bengaluru Rural",
    "Mysore": "Mysuru",
    "Tumkur": "Tumakuru",
    "Bellary": "Ballari",
    "Belgaum": "Belagavi",
    "Gulbarga": "Kalaburagi",
    "Shimoga": "Shivamogga",
    "Chickmagalur": "Chikkamagaluru",
    "Chikmagalur": "Chikkamagaluru",
    "Chamrajanagar": "Chamarajanagar",
    "Chamrajnagar": "Chamarajanagar",

    # already standard
    "Bagalkot": "Bagalkot",
    "Ballari": "Ballari",
    "Bidar": "Bidar",
    "Chitradurga": "Chitradurga",
    "Dakshina Kannada": "Dakshina Kannada",
    "Davanagere": "Davanagere",
    "Dharwad": "Dharwad",
    "Gadag": "Gadag",
    "Hassan": "Hassan",
    "Haveri": "Haveri",
    "Kodagu": "Kodagu",
    "Kolar": "Kolar",
    "Koppal": "Koppal",
    "Mandya": "Mandya",
    "Ramanagara": "Ramanagara",
    "Raichur": "Raichur",
    "Udupi": "Udupi",
    "Uttara Kannada": "Uttara Kannada",
    "Vijayanagara": "Vijayanagara",
    "Yadgir": "Yadgir",
}
df_copy["district"] = df_copy["district"].replace(karnataka_district_mapping)

# %%
uttar_pradesh_district_mapping = {
    "Allahabad": "Prayagraj",
    "Prayagraj": "Prayagraj",
    "Faizabad": "Ayodhya",
    "Ayodhya": "Ayodhya",
    "Raebareli": "Rae Bareli",
    "Bara Banki": "Barabanki",
    "Barabanki": "Barabanki",
    "Bulandshahar": "Bulandshahr",
    "Siddharth Nagar": "Siddharthnagar",
    "Sant Ravidas Nagar Bhadohi": "Bhadohi",
    "Jyotiba Phule Nagar": "Amroha",
    "Kushi Nagar": "Kushinagar",
    "Mahrajganj": "Maharajganj",

    # already standard
    "Agra": "Agra",
    "Aligarh": "Aligarh",
    "Azamgarh": "Azamgarh",
    "Bahraich": "Bahraich",
    "Ballia": "Ballia",
    "Banda": "Banda",
    "Bareilly": "Bareilly",
    "Basti": "Basti",
    "Bijnor": "Bijnor",
    "Chandauli": "Chandauli",
    "Deoria": "Deoria",
    "Etah": "Etah",
    "Etawah": "Etawah",
    "Farrukhabad": "Farrukhabad",
    "Fatehpur": "Fatehpur",
    "Ghazipur": "Ghazipur",
    "Gonda": "Gonda",
    "Gorakhpur": "Gorakhpur",
    "Hardoi": "Hardoi",
    "Hathras": "Hathras",
    "Jaunpur": "Jaunpur",
    "Jhansi": "Jhansi",
    "Kannauj": "Kannauj",
    "Kanpur Dehat": "Kanpur Dehat",
    "Kanpur Nagar": "Kanpur Nagar",
    "Kaushambi": "Kaushambi",
    "Kheri": "Kheri",
    "Lalitpur": "Lalitpur",
    "Lucknow": "Lucknow",
    "Mau": "Mau",
    "Meerut": "Meerut",
    "Mirzapur": "Mirzapur",
    "Moradabad": "Moradabad",
    "Muzaffarnagar": "Muzaffarnagar",
    "Pilibhit": "Pilibhit",
    "Rampur": "Rampur",
    "Saharanpur": "Saharanpur",
    "Shahjahanpur": "Shahjahanpur",
    "Shamli": "Shamli",
    "Sitapur": "Sitapur",
    "Sonbhadra": "Sonbhadra",
    "Sultanpur": "Sultanpur",
    "Unnao": "Unnao",
    "Varanasi": "Varanasi",
}
df_copy["district"] = df_copy["district"].replace(uttar_pradesh_district_mapping)

# %%
maharashtra_district_mapping = {
    "Ahmed Nagar": "Ahmednagar",
    "Ahmadnagar": "Ahmednagar",
    "Aurangabad": "Chhatrapati Sambhajinagar",
    "Chatrapati Sambhaji Nagar": "Chhatrapati Sambhajinagar",
    "Osmanabad": "Dharashiv",
    "Bid": "Beed",
    "Buldana": "Buldhana",
    "Gondia": "Gondiya",

    # already standard / common
    "Akola": "Akola",
    "Amravati": "Amravati",
    "Beed": "Beed",
    "Bhandara": "Bhandara",
    "Chandrapur": "Chandrapur",
    "Dhule": "Dhule",
    "Gadchiroli": "Gadchiroli",
    "Hingoli": "Hingoli",
    "Jalgaon": "Jalgaon",
    "Jalna": "Jalna",
    "Kolhapur": "Kolhapur",
    "Latur": "Latur",
    "Mumbai": "Mumbai",
    "Mumbai City": "Mumbai City",
    "Mumbai Suburban": "Mumbai Suburban",
    "Nagpur": "Nagpur",
    "Nanded": "Nanded",
    "Nandurbar": "Nandurbar",
    "Nashik": "Nashik",
    "Palghar": "Palghar",
    "Parbhani": "Parbhani",
    "Pune": "Pune",
    "Raigad": "Raigad",
    "Ratnagiri": "Ratnagiri",
    "Sangli": "Sangli",
    "Satara": "Satara",
    "Sindhudurg": "Sindhudurg",
    "Solapur": "Solapur",
    "Thane": "Thane",
    "Wardha": "Wardha",
    "Washim": "Washim",
    "Yavatmal": "Yavatmal",
}
df_copy["district"] = df_copy["district"].replace(maharashtra_district_mapping)

# %%
tamil_nadu_district_mapping = {
    "Tuticorin": "Thoothukkudi",
    "Viluppuram": "Villupuram",
    "Kancheepuram": "Kanchipuram",
    "Kanniyakumari": "Kanyakumari",

    # already standard / common
    "Ariyalur": "Ariyalur",
    "Chengalpattu": "Chengalpattu",
    "Chennai": "Chennai",
    "Coimbatore": "Coimbatore",
    "Cuddalore": "Cuddalore",
    "Dharmapuri": "Dharmapuri",
    "Dindigul": "Dindigul",
    "Erode": "Erode",
    "Kallakurichi": "Kallakurichi",
    "Karur": "Karur",
    "Krishnagiri": "Krishnagiri",
    "Madurai": "Madurai",
    "Mayiladuthurai": "Mayiladuthurai",
    "Nagapattinam": "Nagapattinam",
    "Namakkal": "Namakkal",
    "Perambalur": "Perambalur",
    "Pudukkottai": "Pudukkottai",
    "Ramanathapuram": "Ramanathapuram",
    "Ranipet": "Ranipet",
    "Salem": "Salem",
    "Sivaganga": "Sivaganga",
    "Tenkasi": "Tenkasi",
    "Thanjavur": "Thanjavur",
    "The Nilgiris": "The Nilgiris",
    "Theni": "Theni",
    "Thiruvallur": "Thiruvallur",
    "Thiruvarur": "Thiruvarur",
    "Tiruchirappalli": "Tiruchirappalli",
    "Tirunelveli": "Tirunelveli",
    "Tirupattur": "Tirupattur",
    "Tiruppur": "Tiruppur",
    "Tiruvannamalai": "Tiruvannamalai",
    "Vellore": "Vellore",
    "Virudhunagar": "Virudhunagar",
}
df_copy["district"] = df_copy["district"].replace(tamil_nadu_district_mapping)

# %%
gujarat_district_mapping = {
    "Ahmadabad": "Ahmedabad",
    "Ahmed Nagar": "Ahmednagar",   # if appears (otherwise ignore)
    "Surendra Nagar": "Surendranagar",
    "Panch Mahals": "Panchmahals",
    "Sabar Kantha": "Sabarkantha",
    "Kachchh": "Kutch",
    "Dohad": "Dahod",

    # already standard / common
    "Amreli": "Amreli",
    "Anand": "Anand",
    "Arvalli": "Aravalli",
    "Banaskantha": "Banaskantha",
    "Bharuch": "Bharuch",
    "Bhavnagar": "Bhavnagar",
    "Botad": "Botad",
    "Chhotaudepur": "Chhotaudepur",
    "Devbhumi Dwarka": "Devbhumi Dwarka",
    "Gandhinagar": "Gandhinagar",
    "Gir Somnath": "Gir Somnath",
    "Jamnagar": "Jamnagar",
    "Junagadh": "Junagadh",
    "Kheda": "Kheda",
    "Mahesana": "Mehsana",
    "Mahisagar": "Mahisagar",
    "Morbi": "Morbi",
    "Narmada": "Narmada",
    "Navsari": "Navsari",
    "Patan": "Patan",
    "Porbandar": "Porbandar",
    "Rajkot": "Rajkot",
    "Surat": "Surat",
    "Tapi": "Tapi",
    "Vadodara": "Vadodara",
    "Valsad": "Valsad",
}
df_copy["district"] = df_copy["district"].replace(gujarat_district_mapping)

# %%
assam_district_mapping = {
    "North Cachar Hills": "Dima Hasao",
    "Sibsagar": "Sivasagar",

    # already standard / common
    "Baksa": "Baksa",
    "Barpeta": "Barpeta",
    "Biswanath": "Biswanath",
    "Bongaigaon": "Bongaigaon",
    "Cachar": "Cachar",
    "Charaideo": "Charaideo",
    "Chirang": "Chirang",
    "Darrang": "Darrang",
    "Dhemaji": "Dhemaji",
    "Dhubri": "Dhubri",
    "Dibrugarh": "Dibrugarh",
    "Goalpara": "Goalpara",
    "Golaghat": "Golaghat",
    "Hailakandi": "Hailakandi",
    "Hojai": "Hojai",
    "Jorhat": "Jorhat",
    "Kamrup": "Kamrup",
    "Kamrup Metro": "Kamrup Metropolitan",
    "Karimganj": "Karimganj",
    "Kokrajhar": "Kokrajhar",
    "Lakhimpur": "Lakhimpur",
    "Majuli": "Majuli",
    "Marigaon": "Morigaon",
    "Nagaon": "Nagaon",
    "Nalbari": "Nalbari",
    "Sonitpur": "Sonitpur",
    "South Salmara Mankachar": "South Salmara-Mankachar",
    "Tinsukia": "Tinsukia",
    "Udalguri": "Udalguri",
}
df_copy["district"] = df_copy["district"].replace(assam_district_mapping)

# %%
telangana_district_mapping = {
    "K.V. Rangareddy": "Ranga Reddy",
    "K.V.Rangareddy": "Ranga Reddy",
    "Rangareddi": "Ranga Reddy",
    "Mahbub Nagar": "Mahabubnagar",
    "Mahbubnagar": "Mahabubnagar",

    # already standard / common
    "Adilabad": "Adilabad",
    "Bhadradri Kothagudem": "Bhadradri Kothagudem",
    "Hanumakonda": "Hanumakonda",
    "Hyderabad": "Hyderabad",
    "Jagitial": "Jagtial",
    "Jangaon": "Jangaon",
    "Jayashankar Bhupalpally": "Jayashankar Bhupalpally",
    "Jogulamba Gadwal": "Jogulamba Gadwal",
    "Kamareddy": "Kamareddy",
    "Karimnagar": "Karimnagar",
    "Khammam": "Khammam",
    "Komaram Bheem": "Komaram Bheem",
    "Medak": "Medak",
    "Medchal-Malkajgiri": "Medchal-Malkajgiri",
    "Mulugu": "Mulugu",
    "Nagarkurnool": "Nagarkurnool",
    "Nalgonda": "Nalgonda",
    "Narayanpet": "Narayanpet",
    "Nirmal": "Nirmal",
    "Nizamabad": "Nizamabad",
    "Peddapalli": "Peddapalli",
    "Rajanna Sircilla": "Rajanna Sircilla",
    "Sangareddy": "Sangareddy",
    "Siddipet": "Siddipet",
    "Suryapet": "Suryapet",
    "Vikarabad": "Vikarabad",
    "Wanaparthy": "Wanaparthy",
    "Warangal Rural": "Warangal Rural",
    "Warangal Urban": "Warangal Urban",
    "Yadadri": "Yadadri Bhuvanagiri",
}
df_copy["district"] = df_copy["district"].replace(telangana_district_mapping)

# %%
rajasthan_district_mapping = {
    "Dhaulpur": "Dholpur",
    "Chittaurgarh": "Chittorgarh",

    # already standard / common
    "Ajmer": "Ajmer",
    "Alwar": "Alwar",
    "Banswara": "Banswara",
    "Baran": "Baran",
    "Barmer": "Barmer",
    "Bharatpur": "Bharatpur",
    "Bhilwara": "Bhilwara",
    "Bikaner": "Bikaner",
    "Bundi": "Bundi",
    "Churu": "Churu",
    "Dausa": "Dausa",
    "Dungarpur": "Dungarpur",
    "Ganganagar": "Ganganagar",
    "Hanumangarh": "Hanumangarh",
    "Jaipur": "Jaipur",
    "Jaisalmer": "Jaisalmer",
    "Jalore": "Jalore",
    "Jhalawar": "Jhalawar",
    "Jhunjhunu": "Jhunjhunu",
    "Jodhpur": "Jodhpur",
    "Karauli": "Karauli",
    "Kota": "Kota",
    "Nagaur": "Nagaur",
    "Pali": "Pali",
    "Pratapgarh": "Pratapgarh",
    "Rajsamand": "Rajsamand",
    "Sawai Madhopur": "Sawai Madhopur",
    "Sikar": "Sikar",
    "Sirohi": "Sirohi",
    "Tonk": "Tonk",
    "Udaipur": "Udaipur",
}
df_copy["district"] = df_copy["district"].replace(rajasthan_district_mapping)

# %%
madhya_pradesh_district_mapping = {
    "Hoshangabad": "Narmadapuram",
    "East Nimar": "Khandwa",
    "West Nimar": "Khargone",

    # already standard / common
    "Agar Malwa": "Agar Malwa",
    "Alirajpur": "Alirajpur",
    "Anuppur": "Anuppur",
    "Ashok Nagar": "Ashok Nagar",
    "Balaghat": "Balaghat",
    "Barwani": "Barwani",
    "Betul": "Betul",
    "Bhind": "Bhind",
    "Bhopal": "Bhopal",
    "Burhanpur": "Burhanpur",
    "Chhatarpur": "Chhatarpur",
    "Chhindwara": "Chhindwara",
    "Damoh": "Damoh",
    "Datia": "Datia",
    "Dewas": "Dewas",
    "Dhar": "Dhar",
    "Dindori": "Dindori",
    "Guna": "Guna",
    "Gwalior": "Gwalior",
    "Harda": "Harda",
    "Indore": "Indore",
    "Jabalpur": "Jabalpur",
    "Jhabua": "Jhabua",
    "Katni": "Katni",
    "Mandla": "Mandla",
    "Mandsaur": "Mandsaur",
    "Morena": "Morena",
    "Narsinghpur": "Narsinghpur",
    "Neemuch": "Neemuch",
    "Niwari": "Niwari",
    "Panna": "Panna",
    "Raisen": "Raisen",
    "Rajgarh": "Rajgarh",
    "Ratlam": "Ratlam",
    "Rewa": "Rewa",
    "Sagar": "Sagar",
    "Satna": "Satna",
    "Sehore": "Sehore",
    "Seoni": "Seoni",
    "Shahdol": "Shahdol",
    "Shajapur": "Shajapur",
    "Sheopur": "Sheopur",
    "Shivpuri": "Shivpuri",
    "Sidhi": "Sidhi",
    "Singrauli": "Singrauli",
    "Tikamgarh": "Tikamgarh",
    "Ujjain": "Ujjain",
    "Vidisha": "Vidisha",
}
df_copy["district"] = df_copy["district"].replace(madhya_pradesh_district_mapping)

# %%
odisha_district_mapping = {
    "Anugul": "Angul",
    "Sonapur": "Subarnapur",

    # already standard / common
    "Angul": "Angul",
    "Balangir": "Balangir",
    "Baleswar": "Balasore",
    "Bargarh": "Bargarh",
    "Bhadrak": "Bhadrak",
    "Boudh": "Boudh",
    "Cuttack": "Cuttack",
    "Debagarh": "Debagarh",
    "Dhenkanal": "Dhenkanal",
    "Gajapati": "Gajapati",
    "Ganjam": "Ganjam",
    "Jagatsinghapur": "Jagatsinghapur",
    "Jajpur": "Jajpur",
    "Jharsuguda": "Jharsuguda",
    "Kalahandi": "Kalahandi",
    "Kandhamal": "Kandhamal",
    "Kendrapara": "Kendrapara",
    "Kendujhar": "Kendujhar",
    "Khordha": "Khordha",
    "Koraput": "Koraput",
    "Malkangiri": "Malkangiri",
    "Mayurbhanj": "Mayurbhanj",
    "Nabarangapur": "Nabarangapur",
    "Nayagarh": "Nayagarh",
    "Nuapada": "Nuapada",
    "Puri": "Puri",
    "Rayagada": "Rayagada",
    "Sambalpur": "Sambalpur",
    "Sundargarh": "Sundargarh",
}
df_copy["district"] = df_copy["district"].replace(odisha_district_mapping)

# %%
punjab_district_mapping = {
    "Firozpur": "Ferozepur",
    "Muktsar": "Sri Muktsar Sahib",
    "Sas Nagar": "S.A.S Nagar",
    "S.A.S Nagar(Mohali)": "S.A.S Nagar",

    # already standard / common
    "Amritsar": "Amritsar",
    "Barnala": "Barnala",
    "Bathinda": "Bathinda",
    "Faridkot": "Faridkot",
    "Fatehgarh Sahib": "Fatehgarh Sahib",
    "Gurdaspur": "Gurdaspur",
    "Hoshiarpur": "Hoshiarpur",
    "Jalandhar": "Jalandhar",
    "Kapurthala": "Kapurthala",
    "Ludhiana": "Ludhiana",
    "Malerkotla": "Malerkotla",
    "Mansa": "Mansa",
    "Pathankot": "Pathankot",
    "Patiala": "Patiala",
    "Rupnagar": "Rupnagar",
    "Sangrur": "Sangrur",
    "Tarn Taran": "Tarn Taran",
}
df_copy["district"] = df_copy["district"].replace(odisha_district_mapping)

# %%
kerala_district_mapping = {
    "Kasargod": "Kasaragod",

    # already standard / common
    "Alappuzha": "Alappuzha",
    "Ernakulam": "Ernakulam",
    "Idukki": "Idukki",
    "Kannur": "Kannur",
    "Kasaragod": "Kasaragod",
    "Kollam": "Kollam",
    "Kottayam": "Kottayam",
    "Kozhikode": "Kozhikode",
    "Malappuram": "Malappuram",
    "Palakkad": "Palakkad",
    "Pathanamthitta": "Pathanamthitta",
    "Thiruvananthapuram": "Thiruvananthapuram",
    "Thrissur": "Thrissur",
    "Wayanad": "Wayanad",
}
df_copy["district"] = df_copy["district"].replace(kerala_district_mapping)

# %%
haryana_district_mapping = {
    # spelling / format fixes
    "Yamunanagar": "Yamuna Nagar",

    # already standard / common
    "Ambala": "Ambala",
    "Bhiwani": "Bhiwani",
    "Charkhi Dadri": "Charkhi Dadri",
    "Faridabad": "Faridabad",
    "Fatehabad": "Fatehabad",
    "Gurgaon": "Gurugram",
    "Gurugram": "Gurugram",
    "Hisar": "Hisar",
    "Jhajjar": "Jhajjar",
    "Jind": "Jind",
    "Kaithal": "Kaithal",
    "Karnal": "Karnal",
    "Kurukshetra": "Kurukshetra",
    "Mahendragarh": "Mahendragarh",
    "Nuh": "Nuh",
    "Palwal": "Palwal",
    "Panchkula": "Panchkula",
    "Panipat": "Panipat",
    "Rewari": "Rewari",
    "Rohtak": "Rohtak",
    "Sirsa": "Sirsa",
    "Sonipat": "Sonipat",
}
df_copy["district"] = df_copy["district"].replace(haryana_district_mapping)

# %%
jharkhand_district_mapping = {
    # spelling / legacy fixes
    "Hazaribag": "Hazaribagh",
    "Kodarma": "Koderma",
    "Pakaur": "Pakur",
    "Sahebganj": "Sahibganj",
    "Purbi Singhbhum": "East Singhbhum",
    "Pashchimi Singhbhum": "West Singhbhum",

    # already standard / common
    "Bokaro": "Bokaro",
    "Chatra": "Chatra",
    "Deoghar": "Deoghar",
    "Dhanbad": "Dhanbad",
    "Dumka": "Dumka",
    "Garhwa": "Garhwa",
    "Giridih": "Giridih",
    "Godda": "Godda",
    "Gumla": "Gumla",
    "Jamtara": "Jamtara",
    "Khunti": "Khunti",
    "Latehar": "Latehar",
    "Lohardaga": "Lohardaga",
    "Pakur": "Pakur",
    "Palamu": "Palamu",
    "Ramgarh": "Ramgarh",
    "Ranchi": "Ranchi",
    "Saraikela-Kharsawan": "Seraikela-Kharsawan",
    "Simdega": "Simdega",
}
df_copy["district"] = df_copy["district"].replace(jharkhand_district_mapping)

# %%
chhattisgarh_district_mapping = {
    # merged / renamed districts
    "Dakshin Bastar Dantewada": "Dantewada",

    # already standard / common
    "Balod": "Balod",
    "Baloda Bazar": "Baloda Bazar",
    "Bastar": "Bastar",
    "Bemetara": "Bemetara",
    "Bijapur": "Bijapur",
    "Bilaspur": "Bilaspur",
    "Dantewada": "Dantewada",
    "Dhamtari": "Dhamtari",
    "Durg": "Durg",
    "Gariyaband": "Gariyaband",
    "Janjgir-Champa": "Janjgir-Champa",
    "Jashpur": "Jashpur",
    "Kabeerdham": "Kabirdham",
    "Kanker": "Kanker",
    "Kondagaon": "Kondagaon",
    "Korba": "Korba",
    "Mahasamund": "Mahasamund",
    "Mungeli": "Mungeli",
    "Narayanpur": "Narayanpur",
    "Raigarh": "Raigarh",
    "Raipur": "Raipur",
    "Rajnandgaon": "Rajnandgaon",
    "Sukma": "Sukma",
    "Surajpur": "Surajpur",
    "Surguja": "Surguja",
}
df_copy["district"] = df_copy["district"].replace(chhattisgarh_district_mapping)

# %%
delhi_district_mapping = {
    # normalize all to official district names
    "Central Delhi": "Central Delhi",
    "East Delhi": "East Delhi",
    "New Delhi": "New Delhi",
    "North Delhi": "North Delhi",
    "North East Delhi": "North East Delhi",
    "North West Delhi": "North West Delhi",
    "Shahdara": "Shahdara",
    "South Delhi": "South Delhi",
    "South East Delhi": "South East Delhi",
    "South West Delhi": "South West Delhi",
    "West Delhi": "West Delhi",
}
df_copy["district"] = df_copy["district"].replace(delhi_district_mapping)

# %%
uts_district_mapping = {
    # Chandigarh
    "Chandigarh": "Chandigarh",

    # Dadra & Nagar Haveli and Daman & Diu
    "Dadra And Nagar Haveli": "Dadra And Nagar Haveli And Daman And Diu",
    "Daman": "Dadra And Nagar Haveli And Daman And Diu",
    "Diu": "Dadra And Nagar Haveli And Daman And Diu",

    # Jammu & Kashmir / Ladakh
    "Rajauri": "Rajouri",
    "Baramula": "Baramulla",

    # Andaman & Nicobar
    "Andamans": "Andaman And Nicobar Islands",
    "Nicobar": "Nicobar",
    "South Andaman": "South Andaman",
}
df_copy["district"] = df_copy["district"].replace(uts_district_mapping)

# %%
assam_district_mapping = {
    "North Cachar Hills": "Dima Hasao",
    "Sibsagar": "Sivasagar",
    "Marigaon": "Morigaon",
    "Kamrup Metro": "Kamrup Metropolitan",
    "South Salmara Mankachar": "South Salmara-Mankachar",

    # already standard
    "Baksa": "Baksa",
    "Barpeta": "Barpeta",
    "Biswanath": "Biswanath",
    "Bongaigaon": "Bongaigaon",
    "Cachar": "Cachar",
    "Charaideo": "Charaideo",
    "Chirang": "Chirang",
    "Darrang": "Darrang",
    "Dhemaji": "Dhemaji",
    "Dhubri": "Dhubri",
    "Dibrugarh": "Dibrugarh",
    "Goalpara": "Goalpara",
    "Golaghat": "Golaghat",
    "Hailakandi": "Hailakandi",
    "Hojai": "Hojai",
    "Jorhat": "Jorhat",
    "Kamrup": "Kamrup",
    "Karimganj": "Karimganj",
    "Kokrajhar": "Kokrajhar",
    "Lakhimpur": "Lakhimpur",
    "Majuli": "Majuli",
    "Nagaon": "Nagaon",
    "Nalbari": "Nalbari",
    "Sonitpur": "Sonitpur",
    "Tinsukia": "Tinsukia",
    "Udalguri": "Udalguri",
}
df_copy["district"] = df_copy["district"].replace(assam_district_mapping)

# %%
meghalaya_district_mapping = {
    "East Khasi Hills": "East Khasi Hills",
    "West Khasi Hills": "West Khasi Hills",
    "South West Khasi Hills": "South West Khasi Hills",
    "Eastern West Khasi Hills": "Eastern West Khasi Hills",
    "Ri Bhoi": "Ri-Bhoi",
    "West Jaintia Hills": "West Jaintia Hills",
    "East Jaintia Hills": "East Jaintia Hills",
    "West Garo Hills": "West Garo Hills",
    "South Garo Hills": "South Garo Hills",
    "North Garo Hills": "North Garo Hills",
    "South West Garo Hills": "South West Garo Hills",
    "East Garo Hills": "East Garo Hills",
}
df_copy["district"] = df_copy["district"].replace(meghalaya_district_mapping)

# %%
tripura_district_mapping = {
    "West Tripura": "West Tripura",
    "South Tripura": "South Tripura",
    "North Tripura": "North Tripura",
    "Dhalai": "Dhalai",
    "Gomati": "Gomati",
    "Sepahijala": "Sepahijala",
    "Khowai": "Khowai",
    "Unakoti": "Unakoti",
}
df_copy["district"] = df_copy["district"].replace(tripura_district_mapping)

# %%
manipur_district_mapping = {
    "Imphal East": "Imphal East",
    "Imphal West": "Imphal West",
    "Bishnupur": "Bishnupur",
    "Chandel": "Chandel",
    "Churachandpur": "Churachandpur",
    "Senapati": "Senapati",
    "Tamenglong": "Tamenglong",
    "Thoubal": "Thoubal",
    "Ukhrul": "Ukhrul",
    "Jiribam": "Jiribam",
    "Kakching": "Kakching",
    "Kamjong": "Kamjong",
    "Noney": "Noney",
    "Pherzawl": "Pherzawl",
    "Tengnoupal": "Tengnoupal",
}
df_copy["district"] = df_copy["district"].replace(manipur_district_mapping)

# %%
mizoram_district_mapping = {
    "Aizawl": "Aizawl",
    "Lunglei": "Lunglei",
    "Lawngtlai": "Lawngtlai",
    "Saiha": "Saiha",
    "Champhai": "Champhai",
    "Kolasib": "Kolasib",
    "Serchhip": "Serchhip",
    "Mamit": "Mamit",
    "Hnahthial": "Hnahthial",
    "Saitual": "Saitual",
}
df_copy["district"] = df_copy["district"].replace(mizoram_district_mapping)

# %%
nagaland_district_mapping = {
    "Kohima": "Kohima",
    "Dimapur": "Dimapur",
    "Mokokchung": "Mokokchung",
    "Tuensang": "Tuensang",
    "Zunheboto": "Zunheboto",
    "Wokha": "Wokha",
    "Mon": "Mon",
    "Peren": "Peren",
    "Longleng": "Longleng",
    "Kiphire": "Kiphire",
    "Noklak": "Noklak",
}
df_copy["district"] = df_copy["district"].replace(nagaland_district_mapping)

# %%
arunachal_pradesh_district_mapping = {
    "Tawang": "Tawang",
    "West Kameng": "West Kameng",
    "East Kameng": "East Kameng",
    "Papum Pare": "Papum Pare",
    "Kurung Kumey": "Kurung Kumey",
    "Lower Subansiri": "Lower Subansiri",
    "Upper Subansiri": "Upper Subansiri",
    "West Siang": "West Siang",
    "East Siang": "East Siang",
    "Upper Siang": "Upper Siang",
    "Lower Dibang Valley": "Lower Dibang Valley",
    "Dibang Valley": "Dibang Valley",
    "Anjaw": "Anjaw",
    "Changlang": "Changlang",
    "Tirap": "Tirap",
    "Namsai": "Namsai",
    "Siang": "Siang",
    "Shi-Yomi": "Shi-Yomi",
    "Kamle": "Kamle",
    "Kra Daadi": "Kra Daadi",
    "Leparada": "Leparada",
    "Pakke Kessang": "Pakke Kessang",
}
df_copy["district"] = df_copy["district"].replace(arunachal_pradesh_district_mapping)

# %%
jammu_kashmir_district_mapping = {
    "Anantnag": "Anantnag",
    "Bandipore": "Bandipora",
    "Baramula": "Baramulla",
    "Budgam": "Budgam",
    "Badgam": "Budgam",
    "Doda": "Doda",
    "Ganderbal": "Ganderbal",
    "Jammu": "Jammu",
    "Kathua": "Kathua",
    "Kishtwar": "Kishtwar",
    "Kulgam": "Kulgam",
    "Kupwara": "Kupwara",
    "Pulwama": "Pulwama",
    "Rajauri": "Rajouri",
    "Ramban": "Ramban",
    "Reasi": "Reasi",
    "Samba": "Samba",
    "Shopian": "Shopian",
    "Shupiyan": "Shopian",
    "Srinagar": "Srinagar",
    "Udhampur": "Udhampur",
}
df_copy["district"] = df_copy["district"].replace(jammu_kashmir_district_mapping)

# %%
ladakh_district_mapping = {
    "Leh": "Leh",
    "Leh (Ladakh)": "Leh",
    "Kargil": "Kargil",
}
df_copy["district"] = df_copy["district"].replace(ladakh_district_mapping)

# %%
other_uts_district_mapping = {
    # Chandigarh
    "Chandigarh": "Chandigarh",

    # Dadra & Nagar Haveli and Daman & Diu
    "Dadra And Nagar Haveli": "Dadra And Nagar Haveli And Daman And Diu",
    "Daman": "Dadra And Nagar Haveli And Daman And Diu",
    "Diu": "Dadra And Nagar Haveli And Daman And Diu",

    # Andaman & Nicobar Islands
    "Andamans": "Andaman And Nicobar Islands",
    "North And Middle Andaman": "North And Middle Andaman",
    "South Andaman": "South Andaman",
    "Nicobar": "Nicobar",

    # Puducherry
    "Puducherry": "Puducherry",
    "Pondicherry": "Puducherry",
    "Karaikal": "Karaikal",
    "Yanam": "Yanam",
    "Mahe": "Mahe",

    # Lakshadweep
    "Lakshadweep": "Lakshadweep",
}
df_copy["district"] = df_copy["district"].replace(other_uts_district_mapping)

# %%
other_uts_district_mapping = {
    # Chandigarh
    "Chandigarh": "Chandigarh",

    # Dadra & Nagar Haveli and Daman & Diu
    "Dadra And Nagar Haveli": "Dadra And Nagar Haveli And Daman And Diu",
    "Daman": "Dadra And Nagar Haveli And Daman And Diu",
    "Diu": "Dadra And Nagar Haveli And Daman And Diu",

    # Andaman & Nicobar Islands
    "Andamans": "Andaman And Nicobar Islands",
    "North And Middle Andaman": "North And Middle Andaman",
    "South Andaman": "South Andaman",
    "Nicobar": "Nicobar",

    # Puducherry
    "Puducherry": "Puducherry",
    "Pondicherry": "Puducherry",
    "Karaikal": "Karaikal",
    "Yanam": "Yanam",
    "Mahe": "Mahe",

    # Lakshadweep
    "Lakshadweep": "Lakshadweep",
}
df_copy["district"] = df_copy["district"].replace(other_uts_district_mapping)

# %%
district_corrections = {
    # Typos & Encoding Fixes
    'Medchalâ\x88\x92Malkajgiri': 'Medchal-Malkajgiri',
    'Medchal?Malkajgiri': 'Medchal-Malkajgiri',
    'Yadadri.': 'Yadadri Bhuvanagiri',
    'Hooghiy': 'Hooghly',
    'Janjgir - Champa': 'Janjgir-Champa',
    'South 24 Pargana': 'South 24 Parganas',
    'Dist : Thane': 'Thane',

    # Standardization (Aliases)
    'West Medinipur': 'Paschim Medinipur',
    'East Midnapur': 'Purba Medinipur',
    'Ahilyanagar': 'Ahmednagar',
    'Dharashiv': 'Osmanabad',
    'Chhatrapati Sambhajinagar': 'Aurangabad',
    'Sas Nagar': 'S.A.S. Nagar',

    # Invalid / Garbage Entries (Mapped to 'Unknown')
    '5Th Cross': 'Unknown',
    'Near University Thana': 'Unknown',
    'Near Meera Hospital': 'Unknown',
    'Near Uday Nagar Nit Garden': 'Unknown',
    'Near Dhyana Ashram': 'Unknown',
    'Kadiri Road': 'Unknown',
    'Idpl Colony': 'Unknown',
    'Naihati Anandabazar': 'North 24 Parganas',
    'Bally Jagachha': 'Howrah',
    'Domjur': 'Howrah',
    'Mohali': 'S.A.S. Nagar',
    'Poonch': 'Punch',
    'Bandipur': 'Bandipora',
    'Tiruvarur': 'Thiruvarur',
    'Anugal': 'Angul',
    'Nicobars': 'Nicobar',
    'South Dumdum': 'North 24 Parganas',
    'Balianta': 'Khordha',
    'Bicholim': 'North Goa',
    'Tiswadi': 'North Goa',
    'Bardez': 'North Goa',
    # Odisha Fixes
    'Balasore': 'Baleshwar',
    'Jajapur': 'Jajpur',
    'Jagatsinghapur': 'Jagatsinghpur',
    'Baudh': 'Boudh',
    'Khorda': 'Khordha',

    # West Bengal Naming Fixes
    'North Dinajpur': 'Uttar Dinajpur',
    'South Dinajpur': 'Dakshin Dinajpur',
    'West Medinipur': 'Paschim Medinipur',
    'East Midnapur': 'Purba Medinipur',
    'Maldah': 'Malda',
    'Hugli': 'Hooghly',
    'South 24 Pargana': 'South 24 Parganas',

    # Other Spelling Fixes
    'Baudh': 'Boudh',               # Odisha
    'Khorda': 'Khordha',             # Odisha
    'Palamau': 'Palamu',             # Jharkhand
    'Mahabub Nagar': 'Mahabubnagar', # Telangana
    'Karim Nagar': 'Karimnagar',     # Telangana
    'Janjgir Champa': 'Janjgir-Champa', # Chhattisgarh
    'Lahaul And Spiti': 'Lahul And Spiti', # Himachal
    'S.A.S Nagar': 'S.A.S. Nagar',   # Punjab
    'Davanagere': 'Davangere',       # Karnataka
    'Tirupathur': 'Tirupattur',      # Tamil Nadu
    'Banas Kantha': 'Banaskantha',   # Gujarat
    'Jalore': 'Jalor',               # Rajasthan
    'Tamulpur District': 'Tamulpur'  # Assam
}


df_copy["district"] = df_copy["district"].replace(district_corrections)

# %%
df_copy.district.nunique()
# Out:
# 804

# %%
df_copy.isnull().sum()
# Out:
# date             0
# state            0
# district         0
# pincode          0
# demo_age_5_17    0
# demo_age_17_     0
# dtype: int64

# %%
state_districts = df_copy.groupby("state")["district"].unique().reset_index()

# %%
df_copy.to_csv("clean_dataset/cleaned_enrolment_dataset.csv", index=False)

# %%
# !dir
